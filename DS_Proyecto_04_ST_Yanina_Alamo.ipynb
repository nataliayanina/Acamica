# %% [markdown]
# # Proyecto 04 - Series de Tiempo - Add Prophet
#
# ## Dataset: Flujo Vehicular por Unidades de Peaje AUSA
#
# **Recuerda descargar el dataset de [aquí](https://data.buenosaires.gob.ar/dataset/flujo-vehicular-por-unidades-peaje-ausa). Deberás descargar -  al menos para comenzar - los años 2017, 2018 y 2019.**
#
# En este notebook te dejamos unas celdas para que puedas comenzar a trabajar con este dataset para los años 2017, 2018 y 2019. Si deseas utilizar otros años, ten en cuenta que deberás hacer el preprocesamiento correspondiente, ya que la estructura de los datos puede variar.
#
# **Importante:** Para el proyecto, debes comenzar con los datos de la autopista Illia, pago en Efectivo.
#
# ### Exploración de datos
#
# Dedícale un buen tiempo a hacer un Análisis Exploratorio de Datos. Elige preguntas que creas que puedas responder con este dataset. Por ejemplo, ¿Cuáles son los días y horarios de mayor tráfico? También, estudia autocorrelaciones, resampleos, etc.
#
# #### Componentes de la serie
#
# 1. Calcula las componentes estacionales y tendencia de la serie. Interpreta los resultados, si es necesario con información auxiliar (por fuera del dataset) o elementos del dataset que no estés utilizando (por ejemplo, si la tendencia es negativa, ¿puede ser porque se migre a otras formas de pago?).
# 1. ¿La serie posee valores atípicos? Si es así, interpreta, si es necesario con información auxiliar. **Pista**: primer semestre 2019.
#
# ### Predicción a Futuro
#
# Debes implementar un modelo que prediga el tráfico en la autopista Illia para el último trimestre del 2019.
#
# 1. Haz todas las transformaciones de datos que consideres necesarias. Justifica.
# 1. Evalúa de forma apropiada tus resultados. Justifica la métrica elegida.
# 1. Elige un modelo benchmark y compara tus resultados con este modelo.
# 1. Optimiza los hiperparámetros de tu modelo.
# 1. Intenta responder la pregunta: ¿Qué información está usando el modelo para predecir?
# 1. Utiliza el modelo creado para predecir el tráfico en el año 2020. ¿Cómo funciona?
# 1. Si lo deseas, puedes agregar información de años anteriores a 2017. ¿Mejoran los resultados?
#
# ### Para pensar, investigar y, opcionalmente, implementar
# 1. ¿Cómo incorporarías la información sobre tipo de vehículo, forma de pago, sentido, día de la semana, etc.? En lo que respecta a las predicciones, ¿mejoran o empeoran?
# 1. ¿Qué ocurre si comparas las series de tiempo entre distintas estaciones de peajes?¿Tienen el mismo comportamiento o hay alguna que sea distinta a las otras? Si es así, ¿hay información auxiliar que te ayude a explicar lo que encuentras?
# 1. ¿Hay algo que te gustaría investigar o probar?
#
# ### **¡Tómate tiempo para investigar y leer mucho!**
#
# ### 1. Preparación del Dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import datetime
import seaborn as sns
from datetime import datetime, date, time, timedelta
import calendar

# %%
data_2019 = pd.read_csv('Datasets/flujo-vehicular-2019.csv', sep =',')
data_2018 = pd.read_csv('Datasets/flujo-vehicular-2018.csv', sep =',')
data_2017 = pd.read_csv('Datasets/flujo-vehicular-2017.csv', sep =',')

# %%
data_2019.info()
data_2019.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 812153 entries, 0 to 812152
# Data columns (total 10 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   periodo         812153 non-null  int64
#  1   fecha           812153 non-null  object
#  2   hora_inicio     812153 non-null  int64
#  3   hora_fin        812153 non-null  int64
#  4   dia             812153 non-null  object
#  5   estacion        812153 non-null  object
#  6   sentido         812153 non-null  object
#  7   tipo_vehiculo   812153 non-null  object
#  8   forma_pago      812153 non-null  object
#  9   cantidad_pasos  812153 non-null  int64
# dtypes: int64(4), object(6)
# memory usage: 62.0+ MB
#    periodo       fecha  hora_inicio  hora_fin     dia    estacion    sentido  \
# 0     2019  2019-01-01            0         1  Martes     Alberti     Centro
# 1     2019  2019-01-01            0         1  Martes     Alberti     Centro
# 2     2019  2019-01-01            0         1  Martes     Alberti  Provincia
# 3     2019  2019-01-01            0         1  Martes     Alberti  Provincia
# 4     2019  2019-01-01            0         1  Martes  Avellaneda     Centro
#
#   tipo_vehiculo  forma_pago  cantidad_pasos
# 0       Liviano  NO COBRADO              22
# 1       Liviano    TELEPASE               6
# 2       Liviano  NO COBRADO              53
# 3       Liviano    TELEPASE              18
# 4       Liviano    EFECTIVO              16

# %%
data_2018.info()
data_2018.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1375908 entries, 0 to 1375907
# Data columns (total 10 columns):
#  #   Column          Non-Null Count    Dtype
# ---  ------          --------------    -----
#  0   periodo         1375908 non-null  int64
#  1   fecha           1375908 non-null  object
#  2   hora_inicio     1375908 non-null  int64
#  3   hora_fin        1375908 non-null  int64
#  4   dia             1375908 non-null  object
#  5   estacion        1375908 non-null  object
#  6   sentido         1375908 non-null  object
#  7   tipo_vehiculo   1375908 non-null  object
#  8   forma_pago      1375908 non-null  object
#  9   cantidad_pasos  1375908 non-null  int64
# dtypes: int64(4), object(6)
# memory usage: 105.0+ MB
#    periodo       fecha  hora_inicio  hora_fin    dia estacion sentido  \
# 0     2018  2018-01-01            0         1  Lunes  Alberdi  Centro
# 1     2018  2018-01-01            0         1  Lunes  Alberdi  Centro
# 2     2018  2018-01-01            1         2  Lunes  Alberdi  Centro
# 3     2018  2018-01-01            1         2  Lunes  Alberdi  Centro
# 4     2018  2018-01-01            2         3  Lunes  Alberdi  Centro
#
#   tipo_vehiculo  forma_pago  cantidad_pasos
# 0       Liviano  NO COBRADO              29
# 1       Liviano    TELEPASE               9
# 2       Liviano  NO COBRADO              73
# 3       Liviano    TELEPASE              39
# 4       Liviano  NO COBRADO             115

# %%
data_2017.info()
data_2017.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1372645 entries, 0 to 1372644
# Data columns (total 10 columns):
#  #   Column          Non-Null Count    Dtype
# ---  ------          --------------    -----
#  0   periodo         1372645 non-null  int64
#  1   fecha           1372645 non-null  object
#  2   hora_inicio     1372645 non-null  int64
#  3   hora_fin        1372645 non-null  int64
#  4   dia             1372645 non-null  object
#  5   estacion        1372645 non-null  object
#  6   sentido         1372645 non-null  object
#  7   tipo_vehiculo   1372645 non-null  object
#  8   forma_pago      1372645 non-null  object
#  9   cantidad_pasos  1372645 non-null  int64
# dtypes: int64(4), object(6)
# memory usage: 104.7+ MB
#    periodo       fecha  hora_inicio  hora_fin      dia estacion sentido  \
# 0     2017  2017-01-01            0         1  Domingo  Alberdi  Centro
# 1     2017  2017-01-01            0         1  Domingo  Alberdi  Centro
# 2     2017  2017-01-01            1         2  Domingo  Alberdi  Centro
# 3     2017  2017-01-01            1         2  Domingo  Alberdi  Centro
# 4     2017  2017-01-01            1         2  Domingo  Alberdi  Centro
#
#   tipo_vehiculo  forma_pago  cantidad_pasos
# 0       Liviano  NO COBRADO              25
# 1       Liviano    TELEPASE               7
# 2       Liviano  NO COBRADO               5
# 3       Liviano    EFECTIVO               2
# 4       Liviano    EFECTIVO              94

# %% [markdown]
# Investiguemos que valores toman los campos **estacion, sentido, tipo_vehiculo y forma_pago**

# %%
print(data_2019['estacion'].unique())
print(data_2018['estacion'].unique())
print(data_2017['estacion'].unique())
# Out:
# ['Alberti' 'Avellaneda' 'Dellepiane' 'Illia' 'Retiro' 'Salguero'
#  'Sarmiento' 'PDB']
# ['Alberdi' 'Avellaneda' 'Dellepiane Centro' 'Dellepiane Liniers' 'Illia'
#  'Retiro' 'Salguero' 'Sarmiento']
# ['Alberdi' 'Avellaneda' 'Dellepiane Centro' 'Dellepiane Liniers' 'Illia'
#  'Retiro' 'Salguero' 'Sarmiento']

# %%
print(data_2019['sentido'].unique())
print(data_2018['sentido'].unique())
print(data_2017['sentido'].unique())
# Out:
# ['Centro' 'Provincia']
# ['Centro' 'Provincia']
# ['Centro' 'Provincia']

# %%
print(data_2019['tipo_vehiculo'].unique())
print(data_2018['tipo_vehiculo'].unique())
print(data_2017['tipo_vehiculo'].unique())
# Out:
# ['Liviano' 'Pesado']
# ['Liviano' 'Pesado']
# ['Liviano' 'Pesado']

# %%
print(data_2019['forma_pago'].unique())
print(data_2018['forma_pago'].unique())
print(data_2017['forma_pago'].unique())
# Out:
# ['NO COBRADO' 'TELEPASE' 'EFECTIVO' 'EXENTO' 'INFRACCION'
#  'T. DISCAPACIDAD']
# ['NO COBRADO' 'TELEPASE' 'EFECTIVO' 'EXENTO' 'TARJETA DISCAPACIDAD'
#  'INFRACCION']
# ['NO COBRADO' 'TELEPASE' 'EFECTIVO' 'TARJETA DISCAPACIDAD' 'EXENTO'
#  'INFRACCION' 'MONEDERO' 'Otros']

# %% [markdown]
# ##### Podemos decir entonces que los años 2017, 2018 y 2019 tienen las siguientes columnas con la siguiente información:
#
# **periodo**: año del dset
#
# **fecha**: año dia mes
#
# **hora_inicio** hora de inicio de la cuenta de vehiculos (DROP)
#
# **hora_fin** hora de fin de la cuenta de vehiculos (Vamos a usar esta para tomar la hora)
#
# **dia**: dia de la semana
#
# **estacion**: estaciones de peaje, difieren levemente entre los años (Dellepiane se unifica en 2019, antes habia Dellepiane Liniers y Centro, y se agrega PDB)
#
# **sentido**: Centro o Provincia
#
# **tipo_vehiculo**: Liviano o Pesado
#
# **forma_pago**: Hay varias y varian entre los años.
#
# **cantidad_pasos**: Cantidad de vehiculos

# %% [markdown]
# Vamos a estar trabajando con la estación **Illia** y la forma de pago **Efectivo**

# %%
#Unimos los 3 datasets, podemos hacerlo asi directamente ya que tienen las mismas columnas
dataset = pd.concat([data_2019, data_2018, data_2017])
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3560706 entries, 0 to 1372644
# Data columns (total 10 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   periodo         int64
#  1   fecha           object
#  2   hora_inicio     int64
#  3   hora_fin        int64
#  4   dia             object
#  5   estacion        object
#  6   sentido         object
#  7   tipo_vehiculo   object
#  8   forma_pago      object
#  9   cantidad_pasos  int64
# dtypes: int64(4), object(6)
# memory usage: 298.8+ MB

# %% [markdown]
# # Comencemos revisando la distribución de los datos

# %% [markdown]
# ### Distribucion por Forma de Pago

# %%
# Graficamos distribucion por estacion y año
from matplotlib.pyplot import show
dataset_forma_pago=pd.DataFrame(dataset.groupby([dataset.forma_pago, dataset.periodo])['cantidad_pasos'].mean()).reset_index()
dataset_forma_pago=dataset_forma_pago.sort_values(by='cantidad_pasos' ,ascending = False)
plt.figure(figsize=(16,8))
g=sns.barplot(data=dataset_forma_pago,y='cantidad_pasos', x='forma_pago',  palette =sns.color_palette("RdBu",15))
#plt.set_xticklabel( rotation=90) # Rotate labels
plt.title("Pases por año y forma de pago")
plt.ylabel('Promedio de Pasos')
plt.xlabel('Forma Pago')
# Out:
# Text(0.5, 0, 'Forma Pago')

# %%
# Graficamos distribucion por estacion y año
from matplotlib.pyplot import show
dataset_forma_pago=pd.DataFrame(dataset.groupby([dataset.forma_pago, dataset.periodo])['cantidad_pasos'].mean()).reset_index()
dataset_forma_pago=dataset_forma_pago.sort_values(by='cantidad_pasos' ,ascending = False)
plt.figure(figsize=(16,8))
g=sns.barplot(data=dataset_forma_pago,y='cantidad_pasos', x='periodo', hue='forma_pago', palette =sns.color_palette("RdBu",15))
#plt.set_xticklabel( rotation=90) # Rotate labels
plt.title("Pases por año y forma de pago")
plt.ylabel('Promedio de Pasos')
plt.xlabel('Año')
# Out:
# Text(0.5, 0, 'Año')

# %% [markdown]
# ###### La forma de pago que mas se ha usado en todos los periodo es Efectivo

# %% [markdown]
# ### Hagamos una exploracion del trasito por estación y periodo

# %%
dataset_completo_año=pd.DataFrame(dataset.groupby([dataset.estacion, dataset.periodo])['cantidad_pasos'].mean()).reset_index()
dataset_completo_año['Descripcion']=dataset_completo_año["estacion"]+" - "+dataset_completo_año["periodo"].astype(str)
dataset_completo_año.info()
dataset_completo_año
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24 entries, 0 to 23
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   estacion        24 non-null     object
#  1   periodo         24 non-null     int64
#  2   cantidad_pasos  24 non-null     float64
#  3   Descripcion     24 non-null     object
# dtypes: float64(1), int64(1), object(2)
# memory usage: 896.0+ bytes
#               estacion  periodo  cantidad_pasos                Descripcion
# 0              Alberdi     2017       38.447328             Alberdi - 2017
# 1              Alberdi     2018       37.473565             Alberdi - 2018
# 2              Alberti     2019       42.572147             Alberti - 2019
# 3           Avellaneda     2017      129.673669          Avellaneda - 2017
# 4           Avellaneda     2018      125.902688          Avellaneda - 2018
# 5           Avellaneda     2019      259.079853          Avellaneda - 2019
# 6           Dellepiane     2019      156.159104          Dellepiane - 2019
# 7    Dellepiane Centro     2017       88.156123   Dellepiane Centro - 2017
# 8    Dellepiane Centro     2018       87.175054   Dellepiane Centro - 2018
# 9   Dellepiane Liniers     2017       83.699600  Dellepiane Liniers - 2017
# 10  Dellepiane Liniers     2018       81.241732  Dellepiane Liniers - 2018
# 11               Illia     2017      115.007139               Illia - 2017
# 12               Illia     2018      115.151419               Illia - 2018
# 13               Illia     2019      211.968790               Illia - 2019
# 14                 PDB     2019      138.374573                 PDB - 2019
# 15              Retiro     2017       17.613097              Retiro - 2017
# 16              Retiro     2018       11.658695              Retiro - 2018
# 17              Retiro     2019       21.685039              Retiro - 2019
# 18            Salguero     2017       26.381592            Salguero - 2017
# 19            Salguero     2018       33.931677            Salguero - 2018
# 20            Salguero     2019       49.112550            Salguero - 2019
# 21           Sarmiento     2017       41.195658           Sarmiento - 2017
# 22           Sarmiento     2018       40.085123           Sarmiento - 2018
# 23           Sarmiento     2019       50.810687           Sarmiento - 2019

# %%
# Graficamos distribucion por estacion y año
from matplotlib.pyplot import show
dataset_completo_año=dataset_completo_año.sort_values(by='cantidad_pasos' ,ascending = False)
plt.figure(figsize=(16,8))
g=sns.barplot(y=dataset_completo_año.Descripcion, x=dataset_completo_año.cantidad_pasos, palette =sns.color_palette("Oranges_r",33))
#plt.set_xticklabel( rotation=90) # Rotate labels
plt.title("Pases por año y estacion")
plt.ylabel('Estacion + año')
plt.xlabel('Promedio de Pasos')
# Out:
# Text(0.5, 0, 'Promedio de Pasos')

# %% [markdown]
# ###### Por lo que se aprecia, las estaciones mas transitadas fueron en 2019, ya que vemos que estan primeras, y 2019 siempre aparece antes que 2018 y 2017

# %%
# Graficamos distribucion por estacion y año
from matplotlib.pyplot import show
dataset_completo_año=dataset_completo_año.sort_values(by='cantidad_pasos' ,ascending = False)
plt.figure(figsize=(16,8))
g=sns.barplot(y='estacion', x='cantidad_pasos', hue='periodo', data=dataset_completo_año, palette =sns.color_palette("Oranges_r"))
#plt.set_xticklabel( rotation=90) # Rotate labels
plt.title("Pases por estacion")
plt.ylabel('Estacion')
plt.xlabel('Promedio Pasos')
# Out:
# Text(0.5, 0, 'Promedio Pasos')

# %% [raw]
# La estacion Avellaneda es la mas transitada y le sigue la estacion illia, y aca vemos claramente que por estacion la que mas pases tiene es en el año 2019, pero porque habra sido que en 2019 avellaneda crecio el doble?

# %%
# Graficamos distribucion por estacion
from matplotlib.pyplot import show
dataset_completo_año=dataset_completo_año.sort_values(by='cantidad_pasos' ,ascending = False)
plt.figure(figsize=(16,8))
g=sns.barplot(y=dataset_completo_año.estacion, x=dataset_completo_año.cantidad_pasos, palette =sns.color_palette("RdBu",15))
#plt.set_xticklabel( rotation=90) # Rotate labels
plt.title("Pases  por año y estacion")
plt.ylabel('Dia')
plt.xlabel('Promedio Pasos')
# Out:
# Text(0.5, 0, 'Promedio Pasos')

# %%
# Graficamos distribucion por estacion y año
from matplotlib.pyplot import show
dataset_completo_año=dataset_completo_año.sort_values(by='cantidad_pasos' ,ascending = False)
plt.figure(figsize=(16,8))
g=sns.barplot(data=dataset_completo_año,y='cantidad_pasos', x='periodo', hue='estacion', palette =sns.color_palette("RdBu",15))
#plt.set_xticklabel( rotation=90) # Rotate labels
plt.title("Pases  por año y estacion")
plt.ylabel('Promedio de Pasos')
plt.xlabel('Año')
# Out:
# Text(0.5, 0, 'Año')

# %% [raw]
# En estos Graficos se Observa que en 2019 hay nuevas estaciones de paso.

# %% [markdown]
# ### Analicemos la distribucion de las variables por Año

# %%
dataset_Liviano=dataset[(dataset.tipo_vehiculo=="Liviano")]
dataset_Pesado=dataset[(dataset.tipo_vehiculo=="Pesado")]

# %%
# Graficamos distribucion por sentido y dia
from matplotlib.pyplot import show
plt.figure(figsize=(15,5))
g=sns.catplot(data=dataset_Liviano, y='tipo_vehiculo', x='cantidad_pasos',kind="box", orient="h", height=4.5, aspect=1, hue='periodo',palette =sns.color_palette("rocket",3))
g.set(xscale="log")
plt.title("Distribución de trafico Tipo de Vehiculo Liviano y Periodo")


# Graficamos distribucion por sentido y dia
from matplotlib.pyplot import show
plt.figure(figsize=(15,5))
g1=sns.catplot(data=dataset_Pesado, y='tipo_vehiculo', x='cantidad_pasos',kind="box", orient="h", height=4.5, aspect=1, hue='periodo',palette =sns.color_palette("rocket",3))
plt.title("Distribución de trafico Tipo de Vehiculo Pesado y Periodo")
g1.set(xscale="log")

# %% [markdown]
# En esta distribucion observamos como en 2019 impacto los limites de la distribucion , teniendo en cuenta ue observamos que crecio el transito en ese periodo.

# %%
# Graficamos distribucion por sentido y dia
from matplotlib.pyplot import show
plt.figure(figsize=(15,5))
g=sns.catplot(data=dataset_Liviano, y='tipo_vehiculo', x='cantidad_pasos',kind="box", orient="h", height=4.5, aspect=1, hue='sentido',palette =sns.color_palette("rocket",2))
g.set(xscale="log")
plt.title("Distribución de trafico Tipo de Vehiculo Liviano y Periodo")


# Graficamos distribucion por sentido y dia
from matplotlib.pyplot import show
plt.figure(figsize=(15,5))
g1=sns.catplot(data=dataset_Pesado, y='tipo_vehiculo', x='cantidad_pasos',kind="box", orient="h", height=4.5, aspect=1, hue='sentido',palette =sns.color_palette("rocket",2))
plt.title("Distribución de trafico Tipo de Vehiculo Pesado y Periodo")
g1.set(xscale="log")

# %%
# Graficamos distribucion por sentido y dia
from matplotlib.pyplot import show
plt.figure(figsize=(15,5))
g=sns.catplot(data=dataset_Liviano, y='tipo_vehiculo', x='cantidad_pasos',kind="box", orient="h", height=4.5, aspect=1, hue='dia',palette =sns.color_palette("rocket",7))
g.set(xscale="log")
plt.title("Distribución de trafico Tipo de Vehiculo Liviano y Periodo")


# Graficamos distribucion por sentido y dia
from matplotlib.pyplot import show
plt.figure(figsize=(15,5))
g1=sns.catplot(data=dataset_Pesado, y='tipo_vehiculo', x='cantidad_pasos',kind="box", orient="h", height=4.5, aspect=1, hue='dia',palette =sns.color_palette("rocket",7))
plt.title("Distribución de trafico Tipo de Vehiculo Pesado y Periodo")
g1.set(xscale="log")

# %% [markdown]
# ### Que pasara con las formas de pago?

# %%
plt.figure(figsize=(16, 10))
sns.lineplot(data=dataset, x='fecha', y='cantidad_pasos', hue="forma_pago")

#Formato de la gráfica
plt.title('Cantidad de pasos Vs fecha (sin resalmpleo, agregados por: tipo de pago)',fontsize=16)
plt.xlabel('Fecha', fontsize=15)
plt.ylabel('Cantidad de pasos', fontsize=15)
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.tick_params(labelsize=14)
plt.show()

# %%
dataset_analisis =  dataset[['fecha','periodo','forma_pago','cantidad_pasos']].groupby(['periodo','forma_pago']).sum().reset_index()
dataset_analisis
# Out:
#     periodo            forma_pago  cantidad_pasos
# 0      2017              EFECTIVO        69502938
# 1      2017                EXENTO         1677497
# 2      2017            INFRACCION          629550
# 3      2017              MONEDERO              16
# 4      2017            NO COBRADO         4845670
# 5      2017                 Otros              22
# 6      2017  TARJETA DISCAPACIDAD         1565099
# 7      2017              TELEPASE        46612698
# 8      2018              EFECTIVO        60225521
# 9      2018                EXENTO         1250539
# 10     2018            INFRACCION          720320
# 11     2018            NO COBRADO         6072877
# 12     2018  TARJETA DISCAPACIDAD         1061614
# 13     2018              TELEPASE        53762821
# 14     2019              EFECTIVO        53621459
# 15     2019                EXENTO         1310757
# 16     2019            INFRACCION         1098472
# 17     2019            NO COBRADO         6267683
# 18     2019       T. DISCAPACIDAD          841695
# 19     2019              TELEPASE        63570459

# %%
dataset_analisis =  dataset[['fecha','periodo','forma_pago','cantidad_pasos']]\
        .groupby(['fecha', 'periodo','forma_pago'])\
        .sum().reset_index()
dataset_analisis
# Out:
#            fecha  periodo       forma_pago  cantidad_pasos
# 0     2017-01-01     2017         EFECTIVO          157472
# 1     2017-01-01     2017           EXENTO            1638
# 2     2017-01-01     2017       INFRACCION             670
# 3     2017-01-01     2017         MONEDERO               1
# 4     2017-01-01     2017       NO COBRADO            5756
# ...          ...      ...              ...             ...
# 6554  2019-12-31     2019           EXENTO            1817
# 6555  2019-12-31     2019       INFRACCION            1902
# 6556  2019-12-31     2019       NO COBRADO           10375
# 6557  2019-12-31     2019  T. DISCAPACIDAD            1334
# 6558  2019-12-31     2019         TELEPASE           98603
#
# [6559 rows x 4 columns]

# %%
plt.figure(figsize=(16, 10))
sns.lineplot(data=dataset_analisis, x='fecha', y='cantidad_pasos', hue='forma_pago')

#Formato de la gráfica
plt.title('Cantidad de pasos Vs fecha (resampleo:diario, agregado: forma de pago)',fontsize=16)
plt.xlabel('Fecha', fontsize=15)
plt.ylabel('Cantidad de pasos', fontsize=15)
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.tick_params(labelsize=14)
plt.show()

# %% [markdown]
# ###### En esta grafica vemos como la forma de pago Telepase va aumentando en el tiempo, y el ultimo tiempo ha superado a la forma de pago Efectivo

# %% [markdown]
# ### Analisis por Hora

# %%
dataset_analisis=dataset.groupby([dataset.sentido,dataset.hora_fin])['cantidad_pasos'].sum().to_frame().reset_index()
dataset_analisis
# Out:
#       sentido  hora_fin  cantidad_pasos
# 0      Centro         0         3309453
# 1      Centro         1         2538398
# 2      Centro         2         1906822
# 3      Centro         3         1355127
# 4      Centro         4         1090446
# 5      Centro         5         1505996
# 6      Centro         6         3669604
# 7      Centro         7         7918316
# 8      Centro         8        11801844
# 9      Centro         9        12434811
# 10     Centro        10        11761049
# 11     Centro        11        11216048
# 12     Centro        12        11150048
# 13     Centro        13        10993136
# 14     Centro        14        10934817
# 15     Centro        15        10062032
# 16     Centro        16         9742806
# 17     Centro        17         9946185
# 18     Centro        18        10819039
# 19     Centro        19        10695834
# 20     Centro        20         9075879
# 21     Centro        21         8151093
# 22     Centro        22         6524699
# 23     Centro        23         4498188
# 24  Provincia         0         4089436
# 25  Provincia         1         3549783
# 26  Provincia         2         2547413
# 27  Provincia         3         1775642
# 28  Provincia         4         1363733
# 29  Provincia         5         1461937
# 30  Provincia         6         2489953
# 31  Provincia         7         4716783
# 32  Provincia         8         7749275
# 33  Provincia         9         9373258
# 34  Provincia        10         9379367
# 35  Provincia        11         9561913
# 36  Provincia        12        10552551
# 37  Provincia        13        11723148
# 38  Provincia        14        11963018
# 39  Provincia        15        11975203
# 40  Provincia        16        12544727
# 41  Provincia        17        12983221
# 42  Provincia        18        13330143
# 43  Provincia        19        13223166
# 44  Provincia        20        11539797
# 45  Provincia        21        10146701
# 46  Provincia        22         7810123
# 47  Provincia        23         5685746

# %%
plt.figure(figsize=(15, 5))
sns.barplot(x="hora_fin", 
            y="cantidad_pasos", 
            hue='sentido',
            data=dataset_analisis,
            palette= "coolwarm"
            )
plt.title('Cantidad de pasos Vs Hora del día (hue: sentido)',fontsize=16)
plt.xlabel('Hora del día', fontsize=15)
plt.ylabel('Cantidad de pasos', fontsize=15)
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.tick_params(labelsize=14)
plt.show()

# %% [markdown]
# En este grafico podemos ver cuales son los horarios picos, a la mañana y a la tarde, que coincide con la mayoria de la sjornadas laborales y educativas

# %% [markdown]
# # Comenzamos a utilizar el Universo de datos que solicita el proyecto 3

# %%
#Pasamos la columna fecha a formato datetime, y le unimos la hora_fin como hora
dataset['fecha2'] = pd.to_datetime(dataset.fecha) + pd.to_timedelta(dataset.hora_fin, unit = 'h')

# %%
dataset.head(10)
# Out:
#    periodo       fecha  hora_inicio  hora_fin     dia    estacion    sentido  \
# 0     2019  2019-01-01            0         1  Martes     Alberti     Centro
# 1     2019  2019-01-01            0         1  Martes     Alberti     Centro
# 2     2019  2019-01-01            0         1  Martes     Alberti  Provincia
# 3     2019  2019-01-01            0         1  Martes     Alberti  Provincia
# 4     2019  2019-01-01            0         1  Martes  Avellaneda     Centro
# 5     2019  2019-01-01            0         1  Martes  Avellaneda     Centro
# 6     2019  2019-01-01            0         1  Martes  Avellaneda     Centro
# 7     2019  2019-01-01            0         1  Martes  Avellaneda     Centro
# 8     2019  2019-01-01            0         1  Martes  Avellaneda     Centro
# 9     2019  2019-01-01            0         1  Martes  Avellaneda  Provincia
#
#   tipo_vehiculo  forma_pago  cantidad_pasos              fecha2
# 0       Liviano  NO COBRADO              22 2019-01-01 01:00:00
# 1       Liviano    TELEPASE               6 2019-01-01 01:00:00
# 2       Liviano  NO COBRADO              53 2019-01-01 01:00:00
# 3       Liviano    TELEPASE              18 2019-01-01 01:00:00
# 4       Liviano    EFECTIVO              16 2019-01-01 01:00:00
# 5       Liviano      EXENTO               1 2019-01-01 01:00:00
# 6       Liviano  NO COBRADO             276 2019-01-01 01:00:00
# 7       Liviano    TELEPASE             159 2019-01-01 01:00:00
# 8        Pesado    TELEPASE               5 2019-01-01 01:00:00
# 9       Liviano    EFECTIVO              12 2019-01-01 01:00:00

# %%
dataset['fecha_num'] = dataset.fecha2.map(datetime.toordinal)
dataset.head()
# Out:
#    periodo       fecha  hora_inicio  hora_fin     dia    estacion    sentido  \
# 0     2019  2019-01-01            0         1  Martes     Alberti     Centro
# 1     2019  2019-01-01            0         1  Martes     Alberti     Centro
# 2     2019  2019-01-01            0         1  Martes     Alberti  Provincia
# 3     2019  2019-01-01            0         1  Martes     Alberti  Provincia
# 4     2019  2019-01-01            0         1  Martes  Avellaneda     Centro
#
#   tipo_vehiculo  forma_pago  cantidad_pasos              fecha2  fecha_num
# 0       Liviano  NO COBRADO              22 2019-01-01 01:00:00     737060
# 1       Liviano    TELEPASE               6 2019-01-01 01:00:00     737060
# 2       Liviano  NO COBRADO              53 2019-01-01 01:00:00     737060
# 3       Liviano    TELEPASE              18 2019-01-01 01:00:00     737060
# 4       Liviano    EFECTIVO              16 2019-01-01 01:00:00     737060

# %%
#Quitamos las columnas fecha y hora_fin ya que las incluimos en el campo fecha2
dataset.drop(columns=['fecha','hora_fin'], inplace = True)

dataset.head()
# Out:
#    periodo  hora_inicio     dia    estacion    sentido tipo_vehiculo  \
# 0     2019            0  Martes     Alberti     Centro       Liviano
# 1     2019            0  Martes     Alberti     Centro       Liviano
# 2     2019            0  Martes     Alberti  Provincia       Liviano
# 3     2019            0  Martes     Alberti  Provincia       Liviano
# 4     2019            0  Martes  Avellaneda     Centro       Liviano
#
#    forma_pago  cantidad_pasos              fecha2  fecha_num
# 0  NO COBRADO              22 2019-01-01 01:00:00     737060
# 1    TELEPASE               6 2019-01-01 01:00:00     737060
# 2  NO COBRADO              53 2019-01-01 01:00:00     737060
# 3    TELEPASE              18 2019-01-01 01:00:00     737060
# 4    EFECTIVO              16 2019-01-01 01:00:00     737060

# %%
#Corregimos el nombre de fecha2 a fecha
dataset.rename(columns = {'fecha2':'fecha'}, inplace = True) 
dataset.head()
# Out:
#    periodo  hora_inicio     dia    estacion    sentido tipo_vehiculo  \
# 0     2019            0  Martes     Alberti     Centro       Liviano
# 1     2019            0  Martes     Alberti     Centro       Liviano
# 2     2019            0  Martes     Alberti  Provincia       Liviano
# 3     2019            0  Martes     Alberti  Provincia       Liviano
# 4     2019            0  Martes  Avellaneda     Centro       Liviano
#
#    forma_pago  cantidad_pasos               fecha  fecha_num
# 0  NO COBRADO              22 2019-01-01 01:00:00     737060
# 1    TELEPASE               6 2019-01-01 01:00:00     737060
# 2  NO COBRADO              53 2019-01-01 01:00:00     737060
# 3    TELEPASE              18 2019-01-01 01:00:00     737060
# 4    EFECTIVO              16 2019-01-01 01:00:00     737060

# %%
#Nos quedamos solamente con la estación Illia y la forma de pago Efectivo
mask = np.logical_and(dataset.estacion=='Illia', dataset.forma_pago == 'EFECTIVO')
dataset = dataset[mask]

#Quitamos las columnas que no vamos a utilizar
dataset.drop(columns = ['periodo','hora_inicio','forma_pago', 'estacion'], inplace = True)

dataset.head(100)
# Out:
#           dia    sentido tipo_vehiculo  cantidad_pasos               fecha  \
# 80     Martes     Centro       Liviano             537 2019-01-01 02:00:00
# 86     Martes     Centro        Pesado               1 2019-01-01 02:00:00
# 88     Martes  Provincia       Liviano             443 2019-01-01 02:00:00
# 94     Martes  Provincia        Pesado               1 2019-01-01 02:00:00
# 149    Martes     Centro       Liviano             769 2019-01-01 03:00:00
# ...       ...        ...           ...             ...                 ...
# 1940  Viernes  Provincia       Liviano             368 2019-02-01 02:00:00
# 1945  Viernes  Provincia        Pesado               1 2019-02-01 02:00:00
# 2005  Viernes     Centro       Liviano             185 2019-02-01 03:00:00
# 2009  Viernes     Centro        Pesado               7 2019-02-01 03:00:00
# 2012  Viernes  Provincia       Liviano             310 2019-02-01 03:00:00
#
#       fecha_num
# 80       737060
# 86       737060
# 88       737060
# 94       737060
# 149      737060
# ...         ...
# 1940     737091
# 1945     737091
# 2005     737091
# 2009     737091
# 2012     737091
#
# [100 rows x 6 columns]

# %%
#Reordenamos el dataset por fecha
dataset.sort_values('fecha', inplace = True)
dataset.reset_index(drop=True, inplace = True)
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 238869 entries, 0 to 238868
# Data columns (total 6 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   dia             238869 non-null  object
#  1   sentido         238869 non-null  object
#  2   tipo_vehiculo   238869 non-null  object
#  3   cantidad_pasos  238869 non-null  int64
#  4   fecha           238869 non-null  datetime64[ns]
#  5   fecha_num       238869 non-null  int64
# dtypes: datetime64[ns](1), int64(2), object(3)
# memory usage: 10.9+ MB

# %%
# no hay variables correlacionadas, seguramente tendre que encodear los datos para verificar esto
dataset.corr()
# Out:
#                 cantidad_pasos  fecha_num
# cantidad_pasos        1.000000   0.141732
# fecha_num             0.141732   1.000000

# %% [markdown]
# # Analicemos el pase de vehiculos por Dia

# %%
# Vamos a generar por dias diferentes cortes de Datasets
print("Dataset Sentido Centro")
dataset_sentido_centro= dataset[(dataset.sentido == "Centro")]
dataset_sentido_centro= dataset_sentido_centro[['cantidad_pasos','dia']].groupby('dia').mean().reset_index()
dataset_sentido_centro=dataset_sentido_centro.sort_values(by='cantidad_pasos' ,ascending = False)
dataset_sentido_centro
# Out:
# Dataset Sentido Centro
#          dia  cantidad_pasos
# 6    Viernes      211.214388
# 1     Jueves      200.130886
# 4  Miércoles      195.626284
# 3     Martes      192.934342
# 2      Lunes      188.565924
# 5     Sábado      186.336499
# 0    Domingo      177.295910

# %%
print("Dataset Sentido Provincia")
dataset_sentido_provincia =  dataset[(dataset.sentido == "Provincia")]
dataset_sentido_provincia = dataset_sentido_provincia[['cantidad_pasos','dia']].groupby('dia').mean().reset_index()
dataset_sentido_provincia = dataset_sentido_provincia.sort_values(by='cantidad_pasos' ,ascending = False)
dataset_sentido_provincia
# Out:
# Dataset Sentido Provincia
#          dia  cantidad_pasos
# 6    Viernes      224.244641
# 1     Jueves      219.632759
# 4  Miércoles      212.849929
# 3     Martes      208.051592
# 2      Lunes      204.581123
# 5     Sábado      200.842431
# 0    Domingo      186.020959

# %%
print("Dataset tipo Vehiculo Liviano")
dataset_Liviano = dataset[(dataset.tipo_vehiculo == "Liviano")]
dataset_Liviano = dataset_Liviano[['cantidad_pasos','dia']].groupby('dia').mean().reset_index()
dataset_Liviano = dataset_Liviano.sort_values(by='cantidad_pasos' ,ascending = False)
dataset_Liviano
# Out:
# Dataset tipo Vehiculo Liviano
#          dia  cantidad_pasos
# 6    Viernes      591.216803
# 1     Jueves      565.976707
# 4  Miércoles      550.016412
# 3     Martes      531.361668
# 2      Lunes      516.822749
# 5     Sábado      504.612104
# 0    Domingo      453.657205

# %%
print("Dataset tipo Vehiculo Pesado")
dataset_pesado = dataset[(dataset.tipo_vehiculo == "Pesado")]
dataset_pesado = dataset_pesado[['cantidad_pasos','dia']].groupby('dia').mean().reset_index()
dataset_pesado = dataset_pesado.sort_values(by='cantidad_pasos' ,ascending = False)
dataset_pesado
# Out:
# Dataset tipo Vehiculo Pesado
#          dia  cantidad_pasos
# 6    Viernes       11.683796
# 1     Jueves       11.385283
# 4  Miércoles       11.338323
# 3     Martes       10.952252
# 2      Lunes       10.232740
# 5     Sábado        8.191398
# 0    Domingo        6.103821

# %%
print("Dataset completo por dia")
dataset_total_diario = dataset[['cantidad_pasos','dia']].groupby('dia').mean().reset_index()
dataset_total_diario = dataset_total_diario.sort_values(by='cantidad_pasos' ,ascending = False)
dataset_total_diario
# Out:
# Dataset completo por dia
#          dia  cantidad_pasos
# 6    Viernes      217.276736
# 1     Jueves      209.147305
# 4  Miércoles      203.557378
# 3     Martes      199.957798
# 2      Lunes      195.975486
# 5     Sábado      193.149081
# 0    Domingo      181.429677

# %%
# Graficamos distribucion por sentido y dia
from matplotlib.pyplot import show
plt.figure(figsize=(16,3))
g=sns.barplot( x=dataset_total_diario.dia, y=dataset_total_diario.cantidad_pasos, palette =sns.color_palette("BuGn_r",9))
#plt.set_xticklabel( rotation=90) # Rotate labels
plt.title("Pases promedio Diario")
plt.ylabel('Dia')
plt.xlabel('Promedio Pasos')
# Out:
# Text(0.5, 0, 'Promedio Pasos')

# %%
# Graficamos distribucion por sentido y dia
fig, axes = plt.subplots(1,2, figsize=(23, 5), sharey=False) # Genero la estructura del subplot
fig.suptitle('Distribución de trafico por dias por Sentido') # Creo el titulo

# l2
chart_l2=sns.barplot(ax=axes[0], y=dataset_sentido_centro.dia, x=dataset_sentido_centro.cantidad_pasos, palette =sns.color_palette("BuGn_r",9))
axes[0].set_title("Distibución Diaria de trafico sentido Centro ")

# l2
chart_l1=sns.barplot(ax=axes[1], y=dataset_sentido_provincia.dia, x=dataset_sentido_provincia.cantidad_pasos, palette =sns.color_palette("BuGn_r",9))
axes[1].set_title("Distibución Diaria de trafico sentido Provincia ")
# Out:
# Text(0.5, 1.0, 'Distibución Diaria de trafico sentido Provincia ')

# %%
# Graficamos distribucion por tipo de vehiculo y dia
fig, axes = plt.subplots(1,2, figsize=(23, 5), sharey=False) # Genero la estructura del subplot
fig.suptitle('Distribución de trafico por dias y tipo de vehiculo') # Creo el titulo

# l2
chart_l2=sns.barplot(ax=axes[0], y=dataset_Liviano.dia, x=dataset_Liviano.cantidad_pasos, palette =sns.color_palette("BuGn_r",9))
axes[0].set_title("Distibución Diaria de trafico Liviano ")


# l2
chart_l1=sns.barplot(ax=axes[1], y=dataset_pesado.dia, x=dataset_pesado.cantidad_pasos, palette =sns.color_palette("BuGn_r",9))
axes[1].set_title("Distibución Diaria de trafico Pesado ")
# Out:
# Text(0.5, 1.0, 'Distibución Diaria de trafico Pesado ')

# %% [markdown]
# ###### En estos graficos podemos verificar que es cierto que los viernes son los dias con mas trafico

# %%
#Resampleamos nuestros datos para agrupar por dia, y asi tal vez lograr una visualización mas amigable
diario = dataset.resample('D', on = 'fecha').sum()
print(diario.shape)
diario.head()
# Out:
# (1095, 2)
#             cantidad_pasos  fecha_num
# fecha
# 2017-01-01           31183  170092230
# 2017-01-02           51568  232680596
# 2017-01-03           51093  226053924
# 2017-01-04           53332  236362893
# 2017-01-05           56486  234154212

# %% [markdown]
# # Buscamos las fechas faltantes

# %%
#buscamos los dias que no tienen registro, para ellos cargamos el calendario completo
calendario_completo_df = pd.DataFrame(pd.date_range(start='1/1/2017', end='31/12/2019'),columns=['fecha'])
calendario_completo_df.head(10)
# Out:
#        fecha
# 0 2017-01-01
# 1 2017-01-02
# 2 2017-01-03
# 3 2017-01-04
# 4 2017-01-05
# 5 2017-01-06
# 6 2017-01-07
# 7 2017-01-08
# 8 2017-01-09
# 9 2017-01-10

# %%
#merge_validation= dataset.merge(calendario_completo_df, on='fecha', how='left')
merge_validation= calendario_completo_df.merge(dataset, on='fecha', how='left')

# %%
merge_validation.isnull().sum()
# Out:
# fecha              0
# dia               10
# sentido           10
# tipo_vehiculo     10
# cantidad_pasos    10
# fecha_num         10
# dtype: int64

# %%
#merge_validation2.isnull().sum()

# %%
indices_a_reemplazar = merge_validation[merge_validation.cantidad_pasos.isnull()].index
indices_a_reemplazar
# Out:
# Int64Index([1131, 3405, 5875, 6847, 7318, 7515, 7516, 7993, 8413, 9241], dtype='int64')

# %%
merge_validation.iloc[indices_a_reemplazar]
# Out:
#           fecha  dia sentido tipo_vehiculo  cantidad_pasos  fecha_num
# 1131 2017-04-06  NaN     NaN           NaN             NaN        NaN
# 3405 2017-11-04  NaN     NaN           NaN             NaN        NaN
# 5875 2018-06-25  NaN     NaN           NaN             NaN        NaN
# 6847 2018-09-25  NaN     NaN           NaN             NaN        NaN
# 7318 2018-11-10  NaN     NaN           NaN             NaN        NaN
# 7515 2018-11-29  NaN     NaN           NaN             NaN        NaN
# 7516 2018-11-30  NaN     NaN           NaN             NaN        NaN
# 7993 2019-02-11  NaN     NaN           NaN             NaN        NaN
# 8413 2019-05-29  NaN     NaN           NaN             NaN        NaN
# 9241 2019-12-24  NaN     NaN           NaN             NaN        NaN

# %%
merge_validation.head()
# Out:
#        fecha      dia    sentido tipo_vehiculo  cantidad_pasos  fecha_num
# 0 2017-01-01  Domingo  Provincia        Pesado             1.0   736330.0
# 1 2017-01-01  Domingo  Provincia       Liviano             9.0   736330.0
# 2 2017-01-01  Domingo  Provincia       Liviano           644.0   736330.0
# 3 2017-01-01  Domingo  Provincia        Pesado             6.0   736330.0
# 4 2017-01-01  Domingo  Provincia        Pesado             1.0   736330.0

# %%
dataset.head(100)
# Out:
#         dia    sentido tipo_vehiculo  cantidad_pasos               fecha  \
# 0   Domingo  Provincia        Pesado               1 2017-01-01 00:00:00
# 1   Domingo  Provincia       Liviano               9 2017-01-01 00:00:00
# 2   Domingo  Provincia       Liviano             644 2017-01-01 00:00:00
# 3   Domingo  Provincia        Pesado               6 2017-01-01 00:00:00
# 4   Domingo  Provincia        Pesado               1 2017-01-01 00:00:00
# ..      ...        ...           ...             ...                 ...
# 95  Domingo  Provincia       Liviano             556 2017-01-01 12:00:00
# 96  Domingo     Centro       Liviano               9 2017-01-01 12:00:00
# 97  Domingo     Centro       Liviano             510 2017-01-01 12:00:00
# 98  Domingo     Centro        Pesado               1 2017-01-01 12:00:00
# 99  Domingo     Centro        Pesado               6 2017-01-01 12:00:00
#
#     fecha_num
# 0      736330
# 1      736330
# 2      736330
# 3      736330
# 4      736330
# ..        ...
# 95     736330
# 96     736330
# 97     736330
# 98     736330
# 99     736330
#
# [100 rows x 6 columns]

# %%
#Graficamos nuestros datos, tal como están
plt.figure(figsize = (15,6))
plt.plot(dataset.fecha, dataset.cantidad_pasos)
plt.xlabel('Tiempo')
plt.ylabel('Cantidad de autos, por hora')
plt.show()

# %%
plt.figure(figsize = (15,5))
plt.plot(diario.index, diario.cantidad_pasos)
plt.xlabel('Tiempo')
plt.ylabel('Cantidad de autos, por dia')
plt.show()

# %%
#Resampleamos nuestros datos para agrupar por dia, y asi tal vez lograr una visualización mas amigable
semanal = dataset.resample('W', on = 'fecha').sum()
print(semanal.shape)
semanal.head()
# Out:
# (158, 2)
#             cantidad_pasos   fecha_num
# fecha
# 2017-01-01           31183   170092230
# 2017-01-08          347212  1604471696
# 2017-01-15          366413  1605959679
# 2017-01-22          357215  1614074735
# 2017-01-29          354581  1616299175

# %%
#semanal.cantidad_pasos[semanal.cantidad_pasos > 5000000] = np.nan
print(semanal.isna().sum())
#semanal = semanal.interpolate()
print(semanal.isna().sum())
# Out:
# cantidad_pasos    0
# fecha_num         0
# dtype: int64
# cantidad_pasos    0
# fecha_num         0
# dtype: int64

# %%
ventana = int(365*0.3/7)
semanal_promedio_tendencia = semanal.cantidad_pasos.rolling(window=ventana, center = True).mean()
semanal_promedio_tendencia
# Out:
# fecha
# 2017-01-01   NaN
# 2017-01-08   NaN
# 2017-01-15   NaN
# 2017-01-22   NaN
# 2017-01-29   NaN
#               ..
# 2019-12-08   NaN
# 2019-12-15   NaN
# 2019-12-22   NaN
# 2019-12-29   NaN
# 2020-01-05   NaN
# Freq: W-SUN, Name: cantidad_pasos, Length: 158, dtype: float64

# %%
plt.figure(figsize = (15,5))
plt.plot(semanal.index, semanal.cantidad_pasos, label = 'Cantidad de Pasos')
plt.plot(semanal_promedio_tendencia, lw = 4, label = 'Pasos Promedio - Rolling Window')
plt.legend()
plt.xlabel('Fecha')
plt.ylabel('Cantidad de Pases')
plt.show()

# %% [markdown]
# ###### En este grafico podemos observar que la tendencia de transito de la estacion illia y pago ene efectivo es decreciente, y puedo deducir que se esta comenzando a pagar con Telepase

# %% [markdown]
# # ENCODER

# %% [markdown]
# Vamos a encodear infromacion que consideramos relevante para ayudar a nuestra ML

# %%
dataset["date"] =dataset.fecha.dt.date
dataset.head()
# Out:
#        dia    sentido tipo_vehiculo  cantidad_pasos      fecha  fecha_num  \
# 0  Domingo  Provincia        Pesado               1 2017-01-01     736330
# 1  Domingo  Provincia       Liviano               9 2017-01-01     736330
# 2  Domingo  Provincia       Liviano             644 2017-01-01     736330
# 3  Domingo  Provincia        Pesado               6 2017-01-01     736330
# 4  Domingo  Provincia        Pesado               1 2017-01-01     736330
#
#          date
# 0  2017-01-01
# 1  2017-01-01
# 2  2017-01-01
# 3  2017-01-01
# 4  2017-01-01

# %%
dataset.drop(labels=['fecha'], axis=1, inplace=True)
dataset.rename(columns = {'date':'fecha'}, inplace = True) 
dataset.head()
# Out:
#        dia    sentido tipo_vehiculo  cantidad_pasos  fecha_num       fecha
# 0  Domingo  Provincia        Pesado               1     736330  2017-01-01
# 1  Domingo  Provincia       Liviano               9     736330  2017-01-01
# 2  Domingo  Provincia       Liviano             644     736330  2017-01-01
# 3  Domingo  Provincia        Pesado               6     736330  2017-01-01
# 4  Domingo  Provincia        Pesado               1     736330  2017-01-01

# %%
dataset.groupby(["fecha","dia","sentido","tipo_vehiculo"])["cantidad_pasos"].sum().reset_index()
# Out:
#            fecha      dia    sentido tipo_vehiculo  cantidad_pasos
# 0     2017-01-01  Domingo     Centro       Liviano           16681
# 1     2017-01-01  Domingo     Centro        Pesado             370
# 2     2017-01-01  Domingo  Provincia       Liviano           13960
# 3     2017-01-01  Domingo  Provincia        Pesado             172
# 4     2017-01-02    Lunes     Centro       Liviano           26011
# ...          ...      ...        ...           ...             ...
# 4357  2019-12-30    Lunes  Provincia        Pesado             301
# 4358  2019-12-31   Martes     Centro       Liviano           10866
# 4359  2019-12-31   Martes     Centro        Pesado             109
# 4360  2019-12-31   Martes  Provincia       Liviano           10355
# 4361  2019-12-31   Martes  Provincia        Pesado             117
#
# [4362 rows x 5 columns]

# %%
diario_final = dataset.groupby(["fecha","dia","sentido","tipo_vehiculo"])["cantidad_pasos"].sum().reset_index()
print(diario_final.shape)
diario_final.info()
print(diario_final.head())
# Out:
# (4362, 5)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4362 entries, 0 to 4361
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   fecha           4362 non-null   object
#  1   dia             4362 non-null   object
#  2   sentido         4362 non-null   object
#  3   tipo_vehiculo   4362 non-null   object
#  4   cantidad_pasos  4362 non-null   int64
# dtypes: int64(1), object(4)
# memory usage: 170.5+ KB
#         fecha      dia    sentido tipo_vehiculo  cantidad_pasos
# 0  2017-01-01  Domingo     Centro       Liviano           16681
# 1  2017-01-01  Domingo     Centro        Pesado             370
# 2  2017-01-01  Domingo  Provincia       Liviano           13960
# 3  2017-01-01  Domingo  Provincia        Pesado             172
# 4  2017-01-02    Lunes     Centro       Liviano           26011

# %%
diario_final.fecha=pd.to_datetime(diario_final.fecha)

# %%
diario_final["day_num"] = diario_final.fecha.dt.day # Dia
diario_final["month_num"] = diario_final.fecha.dt.month # Mes
diario_final["year_num"] = diario_final.fecha.dt.year # Año
diario_final["Liviano"] =  diario_final["tipo_vehiculo"].apply(lambda x:1 if x =="Liviano" else 0)
diario_final["Pesado"] =  diario_final["tipo_vehiculo"].apply(lambda x:1 if x =="Pesado" else 0)
diario_final["Centro"] =  diario_final["sentido"].apply(lambda x:1 if x =="Centro" else 0)
diario_final["Provincia"] =  diario_final["sentido"].apply(lambda x:1 if x =="Provincia" else 0)

# %%
diario_final.head()
# Out:
#        fecha      dia    sentido tipo_vehiculo  cantidad_pasos  day_num  \
# 0 2017-01-01  Domingo     Centro       Liviano           16681        1
# 1 2017-01-01  Domingo     Centro        Pesado             370        1
# 2 2017-01-01  Domingo  Provincia       Liviano           13960        1
# 3 2017-01-01  Domingo  Provincia        Pesado             172        1
# 4 2017-01-02    Lunes     Centro       Liviano           26011        2
#
#    month_num  year_num  Liviano  Pesado  Centro  Provincia
# 0          1      2017        1       0       1          0
# 1          1      2017        0       1       1          0
# 2          1      2017        1       0       0          1
# 3          1      2017        0       1       0          1
# 4          1      2017        1       0       1          0

# %%
diario_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4362 entries, 0 to 4361
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   fecha           4362 non-null   datetime64[ns]
#  1   dia             4362 non-null   object
#  2   sentido         4362 non-null   object
#  3   tipo_vehiculo   4362 non-null   object
#  4   cantidad_pasos  4362 non-null   int64
#  5   day_num         4362 non-null   int64
#  6   month_num       4362 non-null   int64
#  7   year_num        4362 non-null   int64
#  8   Liviano         4362 non-null   int64
#  9   Pesado          4362 non-null   int64
#  10  Centro          4362 non-null   int64
#  11  Provincia       4362 non-null   int64
# dtypes: datetime64[ns](1), int64(8), object(3)
# memory usage: 409.1+ KB

# %%
diario_final.head(20)
# Out:
#         fecha        dia    sentido tipo_vehiculo  cantidad_pasos  day_num  \
# 0  2017-01-01    Domingo     Centro       Liviano           16681        1
# 1  2017-01-01    Domingo     Centro        Pesado             370        1
# 2  2017-01-01    Domingo  Provincia       Liviano           13960        1
# 3  2017-01-01    Domingo  Provincia        Pesado             172        1
# 4  2017-01-02      Lunes     Centro       Liviano           26011        2
# 5  2017-01-02      Lunes     Centro        Pesado            1814        2
# 6  2017-01-02      Lunes  Provincia       Liviano           22968        2
# 7  2017-01-02      Lunes  Provincia        Pesado             775        2
# 8  2017-01-03     Martes     Centro       Liviano           25577        3
# 9  2017-01-03     Martes     Centro        Pesado            1990        3
# 10 2017-01-03     Martes  Provincia       Liviano           22745        3
# 11 2017-01-03     Martes  Provincia        Pesado             781        3
# 12 2017-01-04  Miércoles     Centro       Liviano           26982        4
# 13 2017-01-04  Miércoles     Centro        Pesado            1967        4
# 14 2017-01-04  Miércoles  Provincia       Liviano           23599        4
# 15 2017-01-04  Miércoles  Provincia        Pesado             784        4
# 16 2017-01-05     Jueves     Centro       Liviano           28787        5
# 17 2017-01-05     Jueves     Centro        Pesado            2033        5
# 18 2017-01-05     Jueves  Provincia       Liviano           24835        5
# 19 2017-01-05     Jueves  Provincia        Pesado             831        5
#
#     month_num  year_num  Liviano  Pesado  Centro  Provincia
# 0           1      2017        1       0       1          0
# 1           1      2017        0       1       1          0
# 2           1      2017        1       0       0          1
# 3           1      2017        0       1       0          1
# 4           1      2017        1       0       1          0
# 5           1      2017        0       1       1          0
# 6           1      2017        1       0       0          1
# 7           1      2017        0       1       0          1
# 8           1      2017        1       0       1          0
# 9           1      2017        0       1       1          0
# 10          1      2017        1       0       0          1
# 11          1      2017        0       1       0          1
# 12          1      2017        1       0       1          0
# 13          1      2017        0       1       1          0
# 14          1      2017        1       0       0          1
# 15          1      2017        0       1       0          1
# 16          1      2017        1       0       1          0
# 17          1      2017        0       1       1          0
# 18          1      2017        1       0       0          1
# 19          1      2017        0       1       0          1

# %%
#Guardamos en un vector los valores categoricos y los valores numericos, esto nos servira en varios pasos como el de Encoding
numerical_features = ['cantidad_pasos', 'fecha_num','day_num','month_num','year_num']
categorical_features = ['sentido','tipo_vehiculo','dia']

# %%
diario_final.drop(labels=categorical_features, axis=1, inplace=True)

# %%
diario_final.set_index("fecha", inplace=True)

# %%
diario_final.head(10)
# Out:
#             cantidad_pasos  day_num  month_num  year_num  Liviano  Pesado  \
# fecha
# 2017-01-01           16681        1          1      2017        1       0
# 2017-01-01             370        1          1      2017        0       1
# 2017-01-01           13960        1          1      2017        1       0
# 2017-01-01             172        1          1      2017        0       1
# 2017-01-02           26011        2          1      2017        1       0
# 2017-01-02            1814        2          1      2017        0       1
# 2017-01-02           22968        2          1      2017        1       0
# 2017-01-02             775        2          1      2017        0       1
# 2017-01-03           25577        3          1      2017        1       0
# 2017-01-03            1990        3          1      2017        0       1
#
#             Centro  Provincia
# fecha
# 2017-01-01       1          0
# 2017-01-01       1          0
# 2017-01-01       0          1
# 2017-01-01       0          1
# 2017-01-02       1          0
# 2017-01-02       1          0
# 2017-01-02       0          1
# 2017-01-02       0          1
# 2017-01-03       1          0
# 2017-01-03       1          0

# %%
diario_final.head()
# Out:
#             cantidad_pasos  day_num  month_num  year_num  Liviano  Pesado  \
# fecha
# 2017-01-01           16681        1          1      2017        1       0
# 2017-01-01             370        1          1      2017        0       1
# 2017-01-01           13960        1          1      2017        1       0
# 2017-01-01             172        1          1      2017        0       1
# 2017-01-02           26011        2          1      2017        1       0
#
#             Centro  Provincia
# fecha
# 2017-01-01       1          0
# 2017-01-01       1          0
# 2017-01-01       0          1
# 2017-01-01       0          1
# 2017-01-02       1          0

# %% [markdown]
# # Train - Test Split

# %%
 diario_final.head()
# Out:
#             cantidad_pasos  day_num  month_num  year_num  Liviano  Pesado  \
# fecha
# 2017-01-01           16681        1          1      2017        1       0
# 2017-01-01             370        1          1      2017        0       1
# 2017-01-01           13960        1          1      2017        1       0
# 2017-01-01             172        1          1      2017        0       1
# 2017-01-02           26011        2          1      2017        1       0
#
#             Centro  Provincia
# fecha
# 2017-01-01       1          0
# 2017-01-01       1          0
# 2017-01-01       0          1
# 2017-01-01       0          1
# 2017-01-02       1          0

# %%
df_train = diario_final.loc['2017-01-01':'2019-09-30'] 
df_train
# Out:
#             cantidad_pasos  day_num  month_num  year_num  Liviano  Pesado  \
# fecha
# 2017-01-01           16681        1          1      2017        1       0
# 2017-01-01             370        1          1      2017        0       1
# 2017-01-01           13960        1          1      2017        1       0
# 2017-01-01             172        1          1      2017        0       1
# 2017-01-02           26011        2          1      2017        1       0
# ...                    ...      ...        ...       ...      ...     ...
# 2019-09-29             226       29          9      2019        0       1
# 2019-09-30           18820       30          9      2019        1       0
# 2019-09-30             406       30          9      2019        0       1
# 2019-09-30           17568       30          9      2019        1       0
# 2019-09-30             376       30          9      2019        0       1
#
#             Centro  Provincia
# fecha
# 2017-01-01       1          0
# 2017-01-01       1          0
# 2017-01-01       0          1
# 2017-01-01       0          1
# 2017-01-02       1          0
# ...            ...        ...
# 2019-09-29       0          1
# 2019-09-30       1          0
# 2019-09-30       1          0
# 2019-09-30       0          1
# 2019-09-30       0          1
#
# [3994 rows x 8 columns]

# %%
df_test = diario_final.loc['2019-10-01':]
df_test
# Out:
#             cantidad_pasos  day_num  month_num  year_num  Liviano  Pesado  \
# fecha
# 2019-10-01           19488        1         10      2019        1       0
# 2019-10-01             698        1         10      2019        0       1
# 2019-10-01           18871        1         10      2019        1       0
# 2019-10-01             612        1         10      2019        0       1
# 2019-10-02           17421        2         10      2019        1       0
# ...                    ...      ...        ...       ...      ...     ...
# 2019-12-30             301       30         12      2019        0       1
# 2019-12-31           10866       31         12      2019        1       0
# 2019-12-31             109       31         12      2019        0       1
# 2019-12-31           10355       31         12      2019        1       0
# 2019-12-31             117       31         12      2019        0       1
#
#             Centro  Provincia
# fecha
# 2019-10-01       1          0
# 2019-10-01       1          0
# 2019-10-01       0          1
# 2019-10-01       0          1
# 2019-10-02       1          0
# ...            ...        ...
# 2019-12-30       0          1
# 2019-12-31       1          0
# 2019-12-31       1          0
# 2019-12-31       0          1
# 2019-12-31       0          1
#
# [368 rows x 8 columns]

# %%
X_train = df_train[['day_num','month_num','year_num','Liviano','Pesado','Centro','Provincia']]
y_train = df_train.cantidad_pasos.values.reshape(-1, 1)
X_test = df_test[['day_num','month_num','year_num','Liviano','Pesado','Centro','Provincia']]
y_test = df_test.cantidad_pasos.values.reshape(-1, 1)

# %%
X_train.shape
y_train.shape
# Out:
# (3994, 1)

# %%
y_train.shape
# Out:
# (3994, 1)

# %% [markdown]
# # Benchmark Con Datos Encoders

# %%
# Modelo de benchmark
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_train_pred = lr.predict(X_train)
y_test_pred= lr.predict(X_test)

# %%
df_train.index
# Out:
# DatetimeIndex(['2017-01-01', '2017-01-01', '2017-01-01', '2017-01-01',
#                '2017-01-02', '2017-01-02', '2017-01-02', '2017-01-02',
#                '2017-01-03', '2017-01-03',
#                ...
#                '2019-09-28', '2019-09-28', '2019-09-29', '2019-09-29',
#                '2019-09-29', '2019-09-29', '2019-09-30', '2019-09-30',
#                '2019-09-30', '2019-09-30'],
#               dtype='datetime64[ns]', name='fecha', length=3994, freq=None)

# %%
df_train.cantidad_pasos
# Out:
# fecha
# 2017-01-01    16681
# 2017-01-01      370
# 2017-01-01    13960
# 2017-01-01      172
# 2017-01-02    26011
#               ...
# 2019-09-29      226
# 2019-09-30    18820
# 2019-09-30      406
# 2019-09-30    17568
# 2019-09-30      376
# Name: cantidad_pasos, Length: 3994, dtype: int64

# %%
df_test.index
# Out:
# DatetimeIndex(['2019-10-01', '2019-10-01', '2019-10-01', '2019-10-01',
#                '2019-10-02', '2019-10-02', '2019-10-02', '2019-10-02',
#                '2019-10-03', '2019-10-03',
#                ...
#                '2019-12-29', '2019-12-29', '2019-12-30', '2019-12-30',
#                '2019-12-30', '2019-12-30', '2019-12-31', '2019-12-31',
#                '2019-12-31', '2019-12-31'],
#               dtype='datetime64[ns]', name='fecha', length=368, freq=None)

# %%
df_test.cantidad_pasos
# Out:
# fecha
# 2019-10-01    19488
# 2019-10-01      698
# 2019-10-01    18871
# 2019-10-01      612
# 2019-10-02    17421
#               ...
# 2019-12-30      301
# 2019-12-31    10866
# 2019-12-31      109
# 2019-12-31    10355
# 2019-12-31      117
# Name: cantidad_pasos, Length: 368, dtype: int64

# %%
df_train.index
# Out:
# DatetimeIndex(['2017-01-01', '2017-01-01', '2017-01-01', '2017-01-01',
#                '2017-01-02', '2017-01-02', '2017-01-02', '2017-01-02',
#                '2017-01-03', '2017-01-03',
#                ...
#                '2019-09-28', '2019-09-28', '2019-09-29', '2019-09-29',
#                '2019-09-29', '2019-09-29', '2019-09-30', '2019-09-30',
#                '2019-09-30', '2019-09-30'],
#               dtype='datetime64[ns]', name='fecha', length=3994, freq=None)

# %%
y_train_pred
# Out:
# array([[23137.29794672],
#        [ 2397.5446261 ],
#        [22433.07310946],
#        ...,
#        [ -394.13253886],
#        [19641.3959445 ],
#        [-1098.35737611]])

# %%
df_test.index
# Out:
# DatetimeIndex(['2019-10-01', '2019-10-01', '2019-10-01', '2019-10-01',
#                '2019-10-02', '2019-10-02', '2019-10-02', '2019-10-02',
#                '2019-10-03', '2019-10-03',
#                ...
#                '2019-12-29', '2019-12-29', '2019-12-30', '2019-12-30',
#                '2019-12-30', '2019-12-30', '2019-12-31', '2019-12-31',
#                '2019-12-31', '2019-12-31'],
#               dtype='datetime64[ns]', name='fecha', length=368, freq=None)

# %%
y_test_pred
# Out:
# array([[20381.20103806],
#        [ -358.55228255],
#        [19676.9762008 ],
#        [-1062.77711981],
#        [20378.90494817],
#        [ -360.84837245],
#        [19674.68011091],
#        [-1065.0732097 ],
#        [20376.60885827],
#        [ -363.14446234],
#        [19672.38402102],
#        [-1067.3692996 ],
#        [20374.31276838],
#        [ -365.44055224],
#        [19670.08793112],
#        [-1069.66538949],
#        [20372.01667848],
#        [ -367.73664213],
#        [19667.79184123],
#        [-1071.96147939],
#        [20369.72058859],
#        [ -370.03273202],
#        [19665.49575133],
#        [-1074.25756928],
#        [20367.4244987 ],
#        [ -372.32882192],
#        [19663.19966144],
#        [-1076.55365917],
#        [20365.1284088 ],
#        [ -374.62491181],
#        [19660.90357155],
#        [-1078.84974907],
#        [20362.83231891],
#        [ -376.9210017 ],
#        [19658.60748165],
#        [-1081.14583896],
#        [20360.53622902],
#        [ -379.2170916 ],
#        [19656.31139176],
#        [-1083.44192885],
#        [20358.24013912],
#        [ -381.51318149],
#        [19654.01530187],
#        [-1085.73801875],
#        [20355.94404923],
#        [ -383.80927139],
#        [19651.71921197],
#        [-1088.03410864],
#        [20353.64795933],
#        [ -386.10536128],
#        [19649.42312208],
#        [-1090.33019854],
#        [20351.35186944],
#        [ -388.40145117],
#        [19647.12703218],
#        [-1092.62628843],
#        [20349.05577955],
#        [ -390.69754107],
#        [19644.83094229],
#        [-1094.92237832],
#        [20346.75968965],
#        [ -392.99363096],
#        [19642.5348524 ],
#        [-1097.21846822],
#        [20344.46359976],
#        [ -395.28972086],
#        [19640.2387625 ],
#        [-1099.51455811],
#        [20342.16750986],
#        [ -397.58581075],
#        [19637.94267261],
#        [-1101.81064801],
#        [20339.87141997],
#        [ -399.88190064],
#        [19635.64658272],
#        [-1104.1067379 ],
#        [20337.57533008],
#        [ -402.17799054],
#        [19633.35049282],
#        [-1106.40282779],
#        [20335.27924018],
#        [ -404.47408043],
#        [19631.05440293],
#        [-1108.69891769],
#        [20332.98315029],
#        [ -406.77017032],
#        [19628.75831303],
#        [-1110.99500758],
#        [20330.6870604 ],
#        [ -409.06626022],
#        [19626.46222314],
#        [-1113.29109747],
#        [20328.3909705 ],
#        [ -411.36235011],
#        [19624.16613325],
#        [-1115.58718737],
#        [20326.09488061],
#        [ -413.65844001],
#        [19621.87004335],
#        [-1117.88327726],
#        [20323.79879071],
#        [ -415.9545299 ],
#        [19619.57395346],
#        [-1120.17936716],
#        [20321.50270082],
#        [ -418.25061979],
#        [19617.27786356],
#        [-1122.47545705],
#        [20319.20661093],
#        [ -420.54670969],
#        [19614.98177367],
#        [-1124.77154694],
#        [20316.91052103],
#        [ -422.84279958],
#        [19612.68568378],
#        [-1127.06763684],
#        [20314.61443114],
#        [ -425.13888948],
#        [19610.38959388],
#        [-1129.36372673],
#        [20312.31834124],
#        [ -427.43497937],
#        [19608.09350399],
#        [-1131.65981663],
#        [20350.19468744],
#        [ -389.55863317],
#        [19645.96985019],
#        [-1093.78347043],
#        [20347.89859755],
#        [ -391.85472307],
#        [19643.67376029],
#        [-1096.07956032],
#        [20345.60250765],
#        [ -394.15081296],
#        [19641.3776704 ],
#        [-1098.37565022],
#        [20343.30641776],
#        [ -396.44690285],
#        [19639.08158051],
#        [-1100.67174011],
#        [20341.01032787],
#        [ -398.74299275],
#        [19636.78549061],
#        [-1102.96783   ],
#        [20338.71423797],
#        [ -401.03908264],
#        [19634.48940072],
#        [-1105.2639199 ],
#        [20336.41814808],
#        [ -403.33517253],
#        [19632.19331082],
#        [-1107.56000979],
#        [20334.12205819],
#        [ -405.63126243],
#        [19629.89722093],
#        [-1109.85609969],
#        [20331.82596829],
#        [ -407.92735232],
#        [19627.60113104],
#        [-1112.15218958],
#        [20329.5298784 ],
#        [ -410.22344222],
#        [19625.30504114],
#        [-1114.44827947],
#        [20327.2337885 ],
#        [ -412.51953211],
#        [19623.00895125],
#        [-1116.74436937],
#        [20324.93769861],
#        [ -414.815622  ],
#        [19620.71286135],
#        [-1119.04045926],
#        [20322.64160872],
#        [ -417.1117119 ],
#        [19618.41677146],
#        [-1121.33654915],
#        [20320.34551882],
#        [ -419.40780179],
#        [19616.12068157],
#        [-1123.63263905],
#        [20318.04942893],
#        [ -421.70389169],
#        [19613.82459167],
#        [-1125.92872894],
#        [20315.75333903],
#        [ -423.99998158],
#        [19611.52850178],
#        [-1128.22481884],
#        [20313.45724914],
#        [ -426.29607147],
#        [19609.23241189],
#        [-1130.52090873],
#        [20311.16115925],
#        [ -428.59216137],
#        [19606.93632199],
#        [-1132.81699862],
#        [20308.86506935],
#        [ -430.88825126],
#        [19604.6402321 ],
#        [-1135.11308852],
#        [20306.56897946],
#        [ -433.18434115],
#        [19602.3441422 ],
#        [-1137.40917841],
#        [20304.27288957],
#        [ -435.48043105],
#        [19600.04805231],
#        [-1139.7052683 ],
#        [20301.97679967],
#        [ -437.77652094],
#        [19597.75196242],
#        [-1142.0013582 ],
#        [20299.68070978],
#        [ -440.07261084],
#        [19595.45587252],
#        [-1144.29744809],
#        [20297.38461988],
#        [ -442.36870073],
#        [19593.15978263],
#        [-1146.59353799],
#        [20295.08852999],
#        [ -444.66479062],
#        [19590.86369273],
#        [-1148.88962788],
#        [20292.7924401 ],
#        [ -446.96088052],
#        [19588.56760284],
#        [-1151.18571777],
#        [20290.4963502 ],
#        [ -449.25697041],
#        [19586.27151295],
#        [-1153.48180767],
#        [20288.20026031],
#        [ -451.55306031],
#        [19583.97542305],
#        [-1155.77789756],
#        [20285.90417042],
#        [ -453.8491502 ],
#        [19581.67933316],
#        [-1158.07398746],
#        [20283.60808052],
#        [ -456.14524009],
#        [19579.38324327],
#        [-1160.37007735],
#        [20319.18833682],
#        [ -420.56498379],
#        [19614.96349957],
#        [-1124.78982105],
#        [20316.89224693],
#        [ -422.86107368],
#        [19612.66740967],
#        [-1127.08591094],
#        [20314.59615704],
#        [ -425.15716358],
#        [19610.37131978],
#        [-1129.38200083],
#        [20312.30006714],
#        [ -427.45325347],
#        [19608.07522989],
#        [-1131.67809073],
#        [20310.00397725],
#        [ -429.74934337],
#        [19605.77913999],
#        [-1133.97418062],
#        [20307.70788736],
#        [ -432.04543326],
#        [19603.4830501 ],
#        [-1136.27027052],
#        [20305.41179746],
#        [ -434.34152315],
#        [19601.18696021],
#        [-1138.56636041],
#        [20303.11570757],
#        [ -436.63761305],
#        [19598.89087031],
#        [-1140.8624503 ],
#        [20300.81961767],
#        [ -438.93370294],
#        [19596.59478042],
#        [-1143.1585402 ],
#        [20298.52352778],
#        [ -441.22979283],
#        [19594.29869052],
#        [-1145.45463009],
#        [20296.22743789],
#        [ -443.52588273],
#        [19592.00260063],
#        [-1147.75071998],
#        [20293.93134799],
#        [ -445.82197262],
#        [19589.70651074],
#        [-1150.04680988],
#        [20291.6352581 ],
#        [ -448.11806252],
#        [19587.41042084],
#        [-1152.34289977],
#        [20289.3391682 ],
#        [ -450.41415241],
#        [19585.11433095],
#        [-1154.63898967],
#        [20287.04307831],
#        [ -452.7102423 ],
#        [19582.81824106],
#        [-1156.93507956],
#        [20284.74698842],
#        [ -455.0063322 ],
#        [19580.52215116],
#        [-1159.23116945],
#        [20282.45089852],
#        [ -457.30242209],
#        [19578.22606127],
#        [-1161.52725935],
#        [20280.15480863],
#        [ -459.59851199],
#        [19575.92997137],
#        [-1163.82334924],
#        [20277.85871874],
#        [ -461.89460188],
#        [19573.63388148],
#        [-1166.11943913],
#        [20275.56262884],
#        [ -464.19069177],
#        [19571.33779159],
#        [-1168.41552903],
#        [20273.26653895],
#        [ -466.48678167],
#        [19569.04170169],
#        [-1170.71161892],
#        [20270.97044905],
#        [ -468.78287156],
#        [19566.7456118 ],
#        [-1173.00770882],
#        [20268.67435916],
#        [ -471.07896145],
#        [19564.4495219 ],
#        [-1175.30379871],
#        [20266.37826927],
#        [ -473.37505135],
#        [19562.15343201],
#        [-1177.5998886 ],
#        [20264.08217937],
#        [ -475.67114124],
#        [19559.85734212],
#        [-1179.8959785 ],
#        [20261.78608948],
#        [ -477.96723114],
#        [19557.56125222],
#        [-1182.19206839],
#        [20259.48999958],
#        [ -480.26332103],
#        [19555.26516233],
#        [-1184.48815829],
#        [20257.19390969],
#        [ -482.55941092],
#        [19552.96907244],
#        [-1186.78424818],
#        [20254.8978198 ],
#        [ -484.85550082],
#        [19550.67298254],
#        [-1189.08033807],
#        [20252.6017299 ],
#        [ -487.15159071],
#        [19548.37689265],
#        [-1191.37642797],
#        [20250.30564001],
#        [ -489.4476806 ],
#        [19546.08080275],
#        [-1193.67251786]])

# %%
plt.figure(figsize = (15,10))
# Series de datos de la gráfica
plt.plot(df_train.index, df_train.cantidad_pasos, label = 'y_train')
plt.plot(df_test.index, df_test.cantidad_pasos, label = 'y_test')
plt.plot(df_train.index, y_train_pred, label = 'y_train_pred', color='yellow', lw = 1)
plt.plot(df_test.index, y_test_pred, label = 'y_test_pred',  lw = 4)

#Formato de la gráfica
plt.title('Predicción con modelo Lineal (Estacion: Illia, tipo de pago: efectivo, resampleo: diario)',fontsize=16)
plt.xlabel('Fecha', fontsize=15)
plt.ylabel('Cantidad de pasos', fontsize=15)
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.tick_params(labelsize=14)
plt.legend()

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
import sklearn

# %%
def evaluar_modelo(modelo, y_train, y_test, y_train_pred, y_test_pred):

    print('El modelo a evaluar: ', modelo)
    ### CALCULAMOS EL ERROR
    
    rmse_train = round(mean_squared_error(y_train, y_train_pred, squared=False),1)
    rmse_test = round(mean_squared_error(y_test, y_test_pred, squared=False),1)
    
    mape_train = round(100*mean_absolute_error(y_train, y_train_pred),1)
    mape_test = round(100*mean_absolute_error(y_test, y_test_pred),1)

    print(f'Raíz del error cuadrático medio en Train: {rmse_train}')
    print(f'Raíz del error cuadrático medio en Test: {rmse_test}')
    print(f'Error Absoluto medio en Train: {mape_train}')
    print(f'Error Absoluto medio en Test: {mape_test}\n')
    
        ### GRAFICAMOS LOS RESULTADOS
      
    plt.figure(figsize = (8,4))

    plt.subplot(1,2,1)
    sns.distplot(y_train - y_train_pred, bins = 20, label = 'train')
    sns.distplot(y_test - y_test_pred, bins = 20, label = 'test')
    plt.xlabel('errores')
    plt.legend()


    ax = plt.subplot(1,2,2)
    ax.scatter(y_test,y_test_pred, s =2)
    
    lims = [
    np.min([ax.get_xlim(), ax.get_ylim()]),  # min of both axes
    np.max([ax.get_xlim(), ax.get_ylim()]),  # max of both axes]
    ]
    
    ax.plot(lims, lims, 'k-', alpha=0.75, zorder=0)
    plt.xlabel('y (test)')
    plt.ylabel('y_pred (test)')
    
    plt.tight_layout()
    plt.show()

# %%
evaluar_modelo('Lineal regressor', y_train, y_test, y_train_pred, y_test_pred)
# Out:
# El modelo a evaluar:  Lineal regressor
# Raíz del error cuadrático medio en Train: 2427.0
# Raíz del error cuadrático medio en Test: 2457.6
# Error Absoluto medio en Train: 162016.2
# Error Absoluto medio en Test: 173301.4
# C:\Users\natalia.alamo\Miniconda3\envs\datascience\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\natalia.alamo\Miniconda3\envs\datascience\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ## Benchmark Con Resampleo Diario

# %%
diario.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1095 entries, 2017-01-01 to 2019-12-31
# Freq: D
# Data columns (total 2 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   cantidad_pasos  1095 non-null   int64
#  1   fecha_num       1095 non-null   int64
# dtypes: int64(2)
# memory usage: 25.7 KB

# %%
df_train_simple = diario.loc['2017-01-01':'2019-09-30'] 
df_train_simple
# Out:
#             cantidad_pasos  fecha_num
# fecha
# 2017-01-01           31183  170092230
# 2017-01-02           51568  232680596
# 2017-01-03           51093  226053924
# 2017-01-04           53332  236362893
# 2017-01-05           56486  234154212
# ...                    ...        ...
# 2019-09-26           43110   70783488
# 2019-09-27           44985   70046255
# 2019-09-28           41925   70783680
# 2019-09-29           38348   70783776
# 2019-09-30           37170   70046540
#
# [1003 rows x 2 columns]

# %%
df_test_simple = diario.loc['2019-10-01':]
df_test_simple
# Out:
#             cantidad_pasos  fecha_num
# fecha
# 2019-10-01           39669   70783968
# 2019-10-02           34943   70784064
# 2019-10-03           35054   70784160
# 2019-10-04           43775   70784256
# 2019-10-05           45150   70784352
# ...                    ...        ...
# 2019-12-27           40182   70792320
# 2019-12-28           30681   70792416
# 2019-12-29           26259   70792512
# 2019-12-30           34523   70055185
# 2019-12-31           21447   65630736
#
# [92 rows x 2 columns]

# %%
X_train_simple = df_train_simple[['fecha_num']]
y_train_simple = df_train_simple.cantidad_pasos.values.reshape(-1, 1)
X_test_simple = df_test_simple[['fecha_num']]
y_test_simple = df_test_simple.cantidad_pasos.values.reshape(-1, 1)

# %%
lr_simple = LinearRegression()

# %%
lr_simple.fit(X_train_simple, y_train_simple)
# Out:
# LinearRegression()

# %%
y_train_pred_s = lr_simple.predict(X_train_simple)
y_test_pred_s= lr_simple.predict(X_test_simple)

# %%
plt.figure(figsize = (15,10))
# Series de datos de la gráfica
plt.plot(df_train_simple.index, df_train_simple.cantidad_pasos, label = 'y_train')
plt.plot(df_test_simple.index, df_test_simple.cantidad_pasos, label = 'y_test')
plt.plot(df_train_simple.index, y_train_pred_s, label = 'y_train_pred', color='yellow', lw = 1)
plt.plot(df_test_simple.index, y_test_pred_s, label = 'y_test_pred',  lw = 4)

#Formato de la gráfica
plt.title('Predicción con modelo Lineal (Estacion: Illia, tipo de pago: efectivo, resampleo: diario)',fontsize=16)
plt.xlabel('Fecha', fontsize=15)
plt.ylabel('Cantidad de pasos', fontsize=15)
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.tick_params(labelsize=14)
plt.legend()

# %% [markdown]
# ###### Como observamos en el resampleo diario, tenemos una prediccion lineal, y no aparece la franja amarilla que tenemos con los Encodeados

# %%
evaluar_modelo('Lineal regressor Resampleo Diario', y_train_simple, y_test_simple, y_train_pred_s, y_test_pred_s)
# Out:
# El modelo a evaluar:  Lineal regressor Resampleo Diario
# Raíz del error cuadrático medio en Train: 6665.2
# Raíz del error cuadrático medio en Test: 5830.4
# Error Absoluto medio en Train: 515617.2
# Error Absoluto medio en Test: 468316.3
# C:\Users\natalia.alamo\Miniconda3\envs\datascience\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\natalia.alamo\Miniconda3\envs\datascience\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ###### Si comparamos el error de la regresion lineal solo con la fecha y el que viene con el Encoder, vemos que teniendo en cuenta solo la fecha el error es el doble

# %% [markdown]
# # XGBoost

# %%
# Importamos la librería que nos permitirá hacer uso del modelo
import xgboost as xgb

# %%
# Instanciaremos el modelo con sus caracteristicas por defecto
reg = xgb.XGBRegressor()

# %%
reg.fit(X_train, y_train,
        eval_set=[(X_train, y_train), (X_test, y_test)],
        eval_metric= ['mape','rmse'],
        early_stopping_rounds=50,
        verbose=1
       )
# Out:
# [0]	validation_0-mape:0.97249	validation_0-rmse:10923.93457	validation_1-mape:0.67291	validation_1-rmse:9450.33691
# [1]	validation_0-mape:0.95577	validation_0-rmse:7808.77978	validation_1-mape:0.51004	validation_1-rmse:6732.87061
# [2]	validation_0-mape:0.98765	validation_0-rmse:5680.59570	validation_1-mape:0.42380	validation_1-rmse:4875.88672
# [3]	validation_0-mape:1.00567	validation_0-rmse:4250.22266	validation_1-mape:0.37774	validation_1-rmse:3615.79736
# [4]	validation_0-mape:1.02808	validation_0-rmse:3327.84473	validation_1-mape:0.35377	validation_1-rmse:2837.13696
# [5]	validation_0-mape:1.04354	validation_0-rmse:2745.47730	validation_1-mape:0.34148	validation_1-rmse:2415.72510
# [6]	validation_0-mape:1.03898	validation_0-rmse:2406.30859	validation_1-mape:0.33715	validation_1-rmse:2218.50537
# [7]	validation_0-mape:1.05246	validation_0-rmse:2205.33057	validation_1-mape:0.33595	validation_1-rmse:2130.59399
# [8]	validation_0-mape:1.05798	validation_0-rmse:2082.25513	validation_1-mape:0.33903	validation_1-rmse:2113.12109
# [9]	validation_0-mape:1.04646	validation_0-rmse:2012.30615	validation_1-mape:0.33262	validation_1-rmse:2047.85584
# [10]	validation_0-mape:1.00288	validation_0-rmse:1957.39136	validation_1-mape:0.33291	validation_1-rmse:2018.64392
# [11]	validation_0-mape:0.99394	validation_0-rmse:1935.85510	validation_1-mape:0.33203	validation_1-rmse:2031.27502
# [12]	validation_0-mape:0.98218	validation_0-rmse:1911.11865	validation_1-mape:0.33261	validation_1-rmse:2021.38940
# [13]	validation_0-mape:0.97521	validation_0-rmse:1890.28992	validation_1-mape:0.32542	validation_1-rmse:1994.23816
# [14]	validation_0-mape:0.97536	validation_0-rmse:1862.53296	validation_1-mape:0.32729	validation_1-rmse:2010.25488
# [15]	validation_0-mape:0.97370	validation_0-rmse:1850.43469	validation_1-mape:0.32505	validation_1-rmse:1997.53979
# [16]	validation_0-mape:0.96991	validation_0-rmse:1841.31470	validation_1-mape:0.32823	validation_1-rmse:1999.02576
# [17]	validation_0-mape:0.94770	validation_0-rmse:1815.71094	validation_1-mape:0.32282	validation_1-rmse:2011.63684
# [18]	validation_0-mape:0.94476	validation_0-rmse:1786.54431	validation_1-mape:0.32335	validation_1-rmse:2022.82886
# [19]	validation_0-mape:0.93109	validation_0-rmse:1774.94055	validation_1-mape:0.38289	validation_1-rmse:2033.76245
# [20]	validation_0-mape:0.92314	validation_0-rmse:1770.44495	validation_1-mape:0.38269	validation_1-rmse:2031.25232
# [21]	validation_0-mape:0.78465	validation_0-rmse:1734.02771	validation_1-mape:0.38977	validation_1-rmse:2036.47266
# [22]	validation_0-mape:0.77870	validation_0-rmse:1717.30029	validation_1-mape:0.42134	validation_1-rmse:2052.81299
# [23]	validation_0-mape:0.77241	validation_0-rmse:1699.49048	validation_1-mape:0.42406	validation_1-rmse:2049.86133
# [24]	validation_0-mape:0.77192	validation_0-rmse:1691.53381	validation_1-mape:0.43044	validation_1-rmse:2051.67725
# [25]	validation_0-mape:0.76911	validation_0-rmse:1675.80591	validation_1-mape:0.44275	validation_1-rmse:2052.65186
# [26]	validation_0-mape:0.76609	validation_0-rmse:1666.58960	validation_1-mape:0.44651	validation_1-rmse:2048.12476
# [27]	validation_0-mape:0.75429	validation_0-rmse:1656.49048	validation_1-mape:0.45265	validation_1-rmse:2049.52466
# [28]	validation_0-mape:0.75380	validation_0-rmse:1648.05640	validation_1-mape:0.47169	validation_1-rmse:2060.46216
# [29]	validation_0-mape:0.73811	validation_0-rmse:1624.60913	validation_1-mape:0.52494	validation_1-rmse:2108.81152
# [30]	validation_0-mape:0.73269	validation_0-rmse:1608.57751	validation_1-mape:0.51950	validation_1-rmse:2107.10425
# [31]	validation_0-mape:0.73365	validation_0-rmse:1591.98584	validation_1-mape:0.51190	validation_1-rmse:2123.32642
# [32]	validation_0-mape:0.74603	validation_0-rmse:1574.16394	validation_1-mape:0.53477	validation_1-rmse:2128.17895
# [33]	validation_0-mape:0.74126	validation_0-rmse:1559.32898	validation_1-mape:0.55885	validation_1-rmse:2170.26245
# [34]	validation_0-mape:0.73481	validation_0-rmse:1547.81738	validation_1-mape:0.54636	validation_1-rmse:2178.78516
# [35]	validation_0-mape:0.77135	validation_0-rmse:1537.09265	validation_1-mape:0.58534	validation_1-rmse:2187.23682
# [36]	validation_0-mape:0.72287	validation_0-rmse:1523.80261	validation_1-mape:0.58777	validation_1-rmse:2188.14697
# [37]	validation_0-mape:0.72213	validation_0-rmse:1512.53284	validation_1-mape:0.59435	validation_1-rmse:2192.87622
# [38]	validation_0-mape:0.70225	validation_0-rmse:1494.57129	validation_1-mape:0.61496	validation_1-rmse:2195.50903
# [39]	validation_0-mape:0.69891	validation_0-rmse:1487.69629	validation_1-mape:0.60459	validation_1-rmse:2201.16968
# [40]	validation_0-mape:0.69167	validation_0-rmse:1479.07874	validation_1-mape:0.60499	validation_1-rmse:2201.55298
# [41]	validation_0-mape:0.68093	validation_0-rmse:1469.40613	validation_1-mape:0.61494	validation_1-rmse:2218.71973
# [42]	validation_0-mape:0.68328	validation_0-rmse:1460.20508	validation_1-mape:0.63319	validation_1-rmse:2224.64575
# [43]	validation_0-mape:0.68893	validation_0-rmse:1449.97229	validation_1-mape:0.63489	validation_1-rmse:2238.21362
# [44]	validation_0-mape:0.69662	validation_0-rmse:1438.23511	validation_1-mape:0.64850	validation_1-rmse:2245.80469
# [45]	validation_0-mape:0.69504	validation_0-rmse:1433.56433	validation_1-mape:0.65671	validation_1-rmse:2242.73218
# [46]	validation_0-mape:0.68644	validation_0-rmse:1427.43726	validation_1-mape:0.64512	validation_1-rmse:2244.21582
# [47]	validation_0-mape:0.68039	validation_0-rmse:1419.55298	validation_1-mape:0.64102	validation_1-rmse:2250.28271
# [48]	validation_0-mape:0.68067	validation_0-rmse:1413.28943	validation_1-mape:0.64050	validation_1-rmse:2279.57495
# [49]	validation_0-mape:0.68468	validation_0-rmse:1408.71094	validation_1-mape:0.63685	validation_1-rmse:2284.45093
# [50]	validation_0-mape:0.66584	validation_0-rmse:1400.08411	validation_1-mape:0.63691	validation_1-rmse:2288.09082
# [51]	validation_0-mape:0.66664	validation_0-rmse:1390.80176	validation_1-mape:0.64891	validation_1-rmse:2291.79077
# [52]	validation_0-mape:0.66850	validation_0-rmse:1384.49231	validation_1-mape:0.65419	validation_1-rmse:2293.59155
# [53]	validation_0-mape:0.65400	validation_0-rmse:1376.14648	validation_1-mape:0.65607	validation_1-rmse:2293.30835
# [54]	validation_0-mape:0.65356	validation_0-rmse:1359.47546	validation_1-mape:0.64772	validation_1-rmse:2293.85889
# [55]	validation_0-mape:0.65864	validation_0-rmse:1346.11902	validation_1-mape:0.65010	validation_1-rmse:2293.81909
# [56]	validation_0-mape:0.66001	validation_0-rmse:1340.68152	validation_1-mape:0.65876	validation_1-rmse:2305.97559
# [57]	validation_0-mape:0.66096	validation_0-rmse:1333.27234	validation_1-mape:0.65844	validation_1-rmse:2309.25830
# [58]	validation_0-mape:0.63587	validation_0-rmse:1320.40271	validation_1-mape:0.65988	validation_1-rmse:2310.47949
# [59]	validation_0-mape:0.64206	validation_0-rmse:1313.39831	validation_1-mape:0.69617	validation_1-rmse:2330.93872
# [60]	validation_0-mape:0.64607	validation_0-rmse:1308.83350	validation_1-mape:0.70640	validation_1-rmse:2348.28467
# [61]	validation_0-mape:0.64433	validation_0-rmse:1303.34338	validation_1-mape:0.70749	validation_1-rmse:2347.90649
# [62]	validation_0-mape:0.64931	validation_0-rmse:1299.77246	validation_1-mape:0.71328	validation_1-rmse:2369.92456
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, gamma=0, gpu_id=-1,
#              importance_type='gain', interaction_constraints='',
#              learning_rate=0.300000012, max_delta_step=0, max_depth=6,
#              min_child_weight=1, missing=nan, monotone_constraints='()',
#              n_estimators=100, n_jobs=8, num_parallel_tree=1, random_state=0,
#              reg_alpha=0, reg_lambda=1, scale_pos_weight=1, subsample=1,
#              tree_method='exact', validate_parameters=1, verbosity=None)

# %%
# Visualizamos el mejor valor para la métrica de criterio de entrenamiento
reg.best_score
# Out:
# 1994.238159

# %%
# Visualizamos cual fue la mejor iteración en la que dicho valor se obtuvo
reg.best_iteration
# Out:
# 13

# %%
# Generamos las predicciones para los valores de test y de de train para graficarlas
y_train_pred = reg.predict(X_train)
y_test_pred= reg.predict(X_test)

# %%
# Generamos el gráfico de comparación de los valores de entrenamiento y de testeo del modelo
plt.figure(figsize = (15,10))
# Series de datos de la gráfica
plt.plot(df_train.index, df_train.cantidad_pasos, label = 'y_train')
plt.plot(df_test.index, df_test.cantidad_pasos, label = 'y_test')
plt.plot(df_train.index, y_train_pred, label = 'y_train_pred', color='yellow', lw = 2)
plt.plot(df_test.index, y_test_pred, label = 'y_test_pred',  lw = 2)
#Formato de la gráfica
plt.title('Predicción con modelo XGBoost (Estacion: Illia, tipo de pago: efectivo, resampleo: diario)',fontsize=16)
plt.xlabel('Fecha', fontsize=14)
plt.ylabel('Cantidad de pasos', fontsize=14)
plt.tick_params(labelsize=14)
plt.legend()

# %%
evaluar_modelo('XGBoost', y_train, y_test, y_train_pred, y_test_pred)
# Out:
# El modelo a evaluar:  XGBoost
# Raíz del error cuadrático medio en Train: 1890.3
# Raíz del error cuadrático medio en Test: 1994.2
# Error Absoluto medio en Train: 110683.1
# Error Absoluto medio en Test: 110219.1
# C:\Users\natalia.alamo\Miniconda3\envs\datascience\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\natalia.alamo\Miniconda3\envs\datascience\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# # XGBoost (Optimización)

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn import datasets
from sklearn.model_selection import RandomizedSearchCV
from sklearn.model_selection import GridSearchCV

# %%
reg
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, gamma=0, gpu_id=-1,
#              importance_type='gain', interaction_constraints='',
#              learning_rate=0.300000012, max_delta_step=0, max_depth=6,
#              min_child_weight=1, missing=nan, monotone_constraints='()',
#              n_estimators=100, n_jobs=8, num_parallel_tree=1, random_state=0,
#              reg_alpha=0, reg_lambda=1, scale_pos_weight=1, subsample=1,
#              tree_method='exact', validate_parameters=1, verbosity=None)

# %%
param_mios = \
{
'base_score':[0.5],
'booster':['gbtree'], 
'colsample_bylevel':[1],
'colsample_bynode':[1], 
'colsample_bytree':[1], 
'gamma':[0], 
'gpu_id':[-1],
'importance_type':['gain'], 
'interaction_constraints':[''],
'learning_rate':[0.300000012, 0.03], 
'max_delta_step':[0], 
'max_depth':[6,5,4,7,8],
'min_child_weight':[1], 
'missing':[np.nan], 
'monotone_constraints':['()'],
'n_estimators':[100,1000], 
'n_jobs':[0], 
'num_parallel_tree':[1], 
'random_state':[0],
'reg_alpha':[0], 
'reg_lambda':[1], 
'scale_pos_weight':[1], 
'subsample':[1],
'tree_method':['exact'], 
'validate_parameters':[1], 
'verbosity':[1]
}

# %%
rg_rs = RandomizedSearchCV(reg, param_mios,n_iter=100, random_state=0, cv=5,
                            scoring='neg_root_mean_squared_error', verbose=True, n_jobs=-1, refit=True)

# %%
rg_rs.fit(X_train, y_train,
        eval_set=[(X_train, y_train), (X_test, y_test)],
        early_stopping_rounds=50,
        verbose=True)
# Out:
# C:\Users\natalia.alamo\Miniconda3\envs\datascience\lib\site-packages\sklearn\model_selection\_search.py:278: UserWarning: The total space of parameters 20 is smaller than n_iter=100. Running 20 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   14.2s
# [0]	validation_0-rmse:10923.94531	validation_1-rmse:9450.33691
# [1]	validation_0-rmse:7814.30225	validation_1-rmse:6732.82080
# [2]	validation_0-rmse:5687.79346	validation_1-rmse:4875.83203
# [3]	validation_0-rmse:4261.01025	validation_1-rmse:3615.68237
# [4]	validation_0-rmse:3346.11060	validation_1-rmse:2854.99561
# [Parallel(n_jobs=-1)]: Done 100 out of 100 | elapsed:   33.0s finished
# [5]	validation_0-rmse:2768.46802	validation_1-rmse:2385.75757
# [6]	validation_0-rmse:2436.03223	validation_1-rmse:2161.66309
# [7]	validation_0-rmse:2248.19019	validation_1-rmse:2074.93677
# [8]	validation_0-rmse:2144.28345	validation_1-rmse:2020.59131
# [9]	validation_0-rmse:2085.28735	validation_1-rmse:2010.85339
# [10]	validation_0-rmse:2051.53735	validation_1-rmse:2012.80811
# [11]	validation_0-rmse:2026.44702	validation_1-rmse:2015.39514
# [12]	validation_0-rmse:2007.76550	validation_1-rmse:2014.31506
# [13]	validation_0-rmse:1997.60107	validation_1-rmse:1984.25378
# [14]	validation_0-rmse:1979.09290	validation_1-rmse:1993.64673
# [15]	validation_0-rmse:1967.64795	validation_1-rmse:1979.29187
# [16]	validation_0-rmse:1956.41565	validation_1-rmse:1994.01807
# [17]	validation_0-rmse:1946.24280	validation_1-rmse:1998.32898
# [18]	validation_0-rmse:1938.88171	validation_1-rmse:1978.94824
# [19]	validation_0-rmse:1923.83386	validation_1-rmse:1990.30676
# [20]	validation_0-rmse:1913.14294	validation_1-rmse:1960.10474
# [21]	validation_0-rmse:1907.36792	validation_1-rmse:1969.21081
# [22]	validation_0-rmse:1895.69959	validation_1-rmse:1970.38660
# [23]	validation_0-rmse:1879.56958	validation_1-rmse:1956.79822
# [24]	validation_0-rmse:1875.40955	validation_1-rmse:1952.92188
# [25]	validation_0-rmse:1864.66394	validation_1-rmse:1962.32117
# [26]	validation_0-rmse:1857.60803	validation_1-rmse:1957.94983
# [27]	validation_0-rmse:1853.19409	validation_1-rmse:1955.60986
# [28]	validation_0-rmse:1841.85242	validation_1-rmse:1967.13013
# [29]	validation_0-rmse:1823.50879	validation_1-rmse:1963.84998
# [30]	validation_0-rmse:1812.56116	validation_1-rmse:1965.89905
# [31]	validation_0-rmse:1804.91894	validation_1-rmse:1973.79468
# [32]	validation_0-rmse:1799.38623	validation_1-rmse:1996.34705
# [33]	validation_0-rmse:1791.70996	validation_1-rmse:2003.35608
# [34]	validation_0-rmse:1787.44995	validation_1-rmse:2023.32666
# [35]	validation_0-rmse:1777.16394	validation_1-rmse:2022.82507
# [36]	validation_0-rmse:1772.37427	validation_1-rmse:2025.88538
# [37]	validation_0-rmse:1762.96875	validation_1-rmse:2035.55981
# [38]	validation_0-rmse:1753.68372	validation_1-rmse:2041.63037
# [39]	validation_0-rmse:1746.92627	validation_1-rmse:2039.68213
# [40]	validation_0-rmse:1737.29407	validation_1-rmse:2023.37280
# [41]	validation_0-rmse:1732.65210	validation_1-rmse:2030.91821
# [42]	validation_0-rmse:1725.54846	validation_1-rmse:2026.45190
# [43]	validation_0-rmse:1718.90967	validation_1-rmse:2033.74487
# [44]	validation_0-rmse:1712.02222	validation_1-rmse:2020.67969
# [45]	validation_0-rmse:1704.56567	validation_1-rmse:2039.32495
# [46]	validation_0-rmse:1697.54199	validation_1-rmse:2047.91113
# [47]	validation_0-rmse:1691.96045	validation_1-rmse:2050.13696
# [48]	validation_0-rmse:1684.40259	validation_1-rmse:2045.76269
# [49]	validation_0-rmse:1680.22266	validation_1-rmse:2045.62756
# [50]	validation_0-rmse:1676.33630	validation_1-rmse:2051.64551
# [51]	validation_0-rmse:1669.70606	validation_1-rmse:2063.17090
# [52]	validation_0-rmse:1664.85059	validation_1-rmse:2071.43359
# [53]	validation_0-rmse:1655.83447	validation_1-rmse:2074.64502
# [54]	validation_0-rmse:1650.36548	validation_1-rmse:2076.71631
# [55]	validation_0-rmse:1646.31384	validation_1-rmse:2083.55566
# [56]	validation_0-rmse:1640.40845	validation_1-rmse:2084.43896
# [57]	validation_0-rmse:1636.14648	validation_1-rmse:2092.54370
# [58]	validation_0-rmse:1632.41028	validation_1-rmse:2105.82715
# [59]	validation_0-rmse:1627.02832	validation_1-rmse:2117.59888
# [60]	validation_0-rmse:1619.67566	validation_1-rmse:2118.29126
# [61]	validation_0-rmse:1613.99658	validation_1-rmse:2139.86719
# [62]	validation_0-rmse:1607.77539	validation_1-rmse:2144.85498
# [63]	validation_0-rmse:1603.05090	validation_1-rmse:2143.76392
# [64]	validation_0-rmse:1597.60913	validation_1-rmse:2142.07007
# [65]	validation_0-rmse:1593.47461	validation_1-rmse:2144.84644
# [66]	validation_0-rmse:1588.99085	validation_1-rmse:2145.48169
# [67]	validation_0-rmse:1584.57471	validation_1-rmse:2152.31274
# [68]	validation_0-rmse:1577.15015	validation_1-rmse:2158.98926
# [69]	validation_0-rmse:1573.09570	validation_1-rmse:2158.54614
# [70]	validation_0-rmse:1566.19421	validation_1-rmse:2158.35352
# [71]	validation_0-rmse:1556.31812	validation_1-rmse:2163.04565
# [72]	validation_0-rmse:1552.90027	validation_1-rmse:2162.21069
# [73]	validation_0-rmse:1547.87927	validation_1-rmse:2174.14526
# [74]	validation_0-rmse:1543.49023	validation_1-rmse:2186.87964
# RandomizedSearchCV(cv=5,
#                    estimator=XGBRegressor(base_score=0.5, booster='gbtree',
#                                           colsample_bylevel=1,
#                                           colsample_bynode=1,
#                                           colsample_bytree=1, gamma=0,
#                                           gpu_id=-1, importance_type='gain',
#                                           interaction_constraints='',
#                                           learning_rate=0.300000012,
#                                           max_delta_step=0, max_depth=6,
#                                           min_child_weight=1, missing=nan,
#                                           monotone_constraints='()',
#                                           n_estimators=100, n_jobs=8,
#                                           num_par...
#                                         'min_child_weight': [1],
#                                         'missing': [nan],
#                                         'monotone_constraints': ['()'],
#                                         'n_estimators': [100, 1000],
#                                         'n_jobs': [0], 'num_parallel_tree': [1],
#                                         'random_state': [0], 'reg_alpha': [0],
#                                         'reg_lambda': [1],
#                                         'scale_pos_weight': [1],
#                                         'subsample': [1],
#                                         'tree_method': ['exact'],
#                                         'validate_parameters': [1],
#                                         'verbosity': [1]},
#                    random_state=0, scoring='neg_root_mean_squared_error',
#                    verbose=True)

# %%
rg_rs.best_score_
# Out:
# -2459.4098393422614

# %%
rg_rs.best_estimator_
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, gamma=0, gpu_id=-1,
#              importance_type='gain', interaction_constraints='',
#              learning_rate=0.300000012, max_delta_step=0, max_depth=5,
#              min_child_weight=1, missing=nan, monotone_constraints='()',
#              n_estimators=100, n_jobs=0, num_parallel_tree=1, random_state=0,
#              reg_alpha=0, reg_lambda=1, scale_pos_weight=1, subsample=1,
#              tree_method='exact', validate_parameters=1, verbosity=1)

# %%
list(rg_rs.cv_results_.keys())
# Out:
# ['mean_fit_time',
#  'std_fit_time',
#  'mean_score_time',
#  'std_score_time',
#  'param_verbosity',
#  'param_validate_parameters',
#  'param_tree_method',
#  'param_subsample',
#  'param_scale_pos_weight',
#  'param_reg_lambda',
#  'param_reg_alpha',
#  'param_random_state',
#  'param_num_parallel_tree',
#  'param_n_jobs',
#  'param_n_estimators',
#  'param_monotone_constraints',
#  'param_missing',
#  'param_min_child_weight',
#  'param_max_depth',
#  'param_max_delta_step',
#  'param_learning_rate',
#  'param_interaction_constraints',
#  'param_importance_type',
#  'param_gpu_id',
#  'param_gamma',
#  'param_colsample_bytree',
#  'param_colsample_bynode',
#  'param_colsample_bylevel',
#  'param_booster',
#  'param_base_score',
#  'params',
#  'split0_test_score',
#  'split1_test_score',
#  'split2_test_score',
#  'split3_test_score',
#  'split4_test_score',
#  'mean_test_score',
#  'std_test_score',
#  'rank_test_score']

# %%
best_score = np.argmax(rg_rs.cv_results_['mean_test_score'])
best_score
# Out:
# 2

# %%
print('mean_test_f1', rg_rs.cv_results_['mean_test_score'][best_score])
print('params', rg_rs.cv_results_['params'][best_score])
# Out:
# mean_test_f1 -2459.4098393422614
# params {'verbosity': 1, 'validate_parameters': 1, 'tree_method': 'exact', 'subsample': 1, 'scale_pos_weight': 1, 'reg_lambda': 1, 'reg_alpha': 0, 'random_state': 0, 'num_parallel_tree': 1, 'n_jobs': 0, 'n_estimators': 100, 'monotone_constraints': '()', 'missing': nan, 'min_child_weight': 1, 'max_depth': 5, 'max_delta_step': 0, 'learning_rate': 0.300000012, 'interaction_constraints': '', 'importance_type': 'gain', 'gpu_id': -1, 'gamma': 0, 'colsample_bytree': 1, 'colsample_bynode': 1, 'colsample_bylevel': 1, 'booster': 'gbtree', 'base_score': 0.5}

# %%
y_train_pred = rg_rs.predict(X_train)
y_test_pred= rg_rs.predict(X_test)

# %%
plt.figure(figsize = (14,5))
# Series de datos de la gráfica
plt.plot(df_train.index, df_train.cantidad_pasos, label = 'y_train')
plt.plot(df_test.index, df_test.cantidad_pasos, label = 'y_test')
plt.plot(df_train.index, y_train_pred, label = 'y_train_pred', color='yellow', lw = 2)
plt.plot(df_test.index, y_test_pred, label = 'y_test_pred',  lw = 2)
#Formato de la gráfica
plt.title('Predicción con modelo XGBoost (Estacion: Illia, tipo de pago: efectivo, resampleo: diario)',fontsize=16)
plt.xlabel('Fecha', fontsize=14)
plt.ylabel('Cantidad de pasos', fontsize=14)
plt.legend()

# %%
evaluar_modelo('XGBoost_optimizado', y_train, y_test, y_train_pred, y_test_pred)
# Out:
# El modelo a evaluar:  XGBoost_optimizado
# Raíz del error cuadrático medio en Train: 1875.4
# Raíz del error cuadrático medio en Test: 1952.9
# Error Absoluto medio en Train: 108800.7
# Error Absoluto medio en Test: 115010.0
# C:\Users\natalia.alamo\Miniconda3\envs\datascience\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\natalia.alamo\Miniconda3\envs\datascience\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ##### Este ultimo Modelo "XGBoost_optimizado" es el modelo que nos da el error mas bajo, y el mas optimo.

# %% [markdown]
# # Variables mas importantes  para la predicción

# %%
import xgboost as xgb
from xgboost import plot_importance, plot_tree

# %%
plot_importance(reg, height=0.8,max_num_features=15)
plt.title('Predicción con modelo XGBoost (Múltiples parametros) Feature importance',fontsize=16)
plt.xlabel('Feature', fontsize=15)
plt.ylabel('F score', fontsize=15)
plt.tick_params(labelsize=14)
plt.show()

# %% [markdown]
# # Forecast 2020

# %% [markdown]
# Predicción a Futuro
#
# Debes implementar un modelo que prediga el tráfico en la autopista Illia para el último trimestre del 2019.
#
# Haz todas las transformaciones de datos que consideres necesarias. Justifica.
# Evalúa de forma apropiada tus resultados. Justifica la métrica elegida.
# Elige un modelo benchmark y compara tus resultados con este modelo.
# Optimiza los hiperparámetros de tu modelo.
# Intenta responder la pregunta: ¿Qué información está usando el modelo para predecir?
# Utiliza el modelo creado para predecir el tráfico en el año 2020. ¿Cómo funciona?
# Si lo deseas, puedes agregar información de años anteriores a 2017. ¿Mejoran los resultados?

# %%
diario.head()
# Out:
#             cantidad_pasos  fecha_num
# fecha
# 2017-01-01           31183  170092230
# 2017-01-02           51568  232680596
# 2017-01-03           51093  226053924
# 2017-01-04           53332  236362893
# 2017-01-05           56486  234154212

# %%
#Armamos nuestro dataset para poder buscar la predicción de 2020
df_prophet = diario.reset_index().drop(columns='fecha_num').rename(columns={'fecha':'ds', 'cantidad_pasos':'y'})
df_prophet
# Out:
#              ds      y
# 0    2017-01-01  31183
# 1    2017-01-02  51568
# 2    2017-01-03  51093
# 3    2017-01-04  53332
# 4    2017-01-05  56486
# ...         ...    ...
# 1090 2019-12-27  40182
# 1091 2019-12-28  30681
# 1092 2019-12-29  26259
# 1093 2019-12-30  34523
# 1094 2019-12-31  21447
#
# [1095 rows x 2 columns]

# %%
# Omitimos los diferentes warnings que se generan con el uso de las librerias
import warnings
warnings.simplefilter('ignore')

# %%
# Importamos la librería
from fbprophet import Prophet

# %%
# Instanciamos el modelo
prophet_model = Prophet()

# %%
# Entrenamos nuestro modelo con los datos de entrenamiento
prophet_model.fit(df_prophet)
# Out:
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
#Buscamos las fechas futuras, proceso que solo funciona con Prophet
future = prophet_model.make_future_dataframe(periods=365)
future.tail()
# Out:
#              ds
# 1455 2020-12-26
# 1456 2020-12-27
# 1457 2020-12-28
# 1458 2020-12-29
# 1459 2020-12-30

# %%
forecast = prophet_model.predict(future)
forecast
# Out:
#              ds         trend    yhat_lower    yhat_upper   trend_lower  \
# 0    2017-01-01  48904.328644  31719.835330  46430.328311  48904.328644
# 1    2017-01-02  48903.472430  37322.283536  52164.677281  48903.472430
# 2    2017-01-03  48902.616217  38428.037715  52689.905953  48902.616217
# 3    2017-01-04  48901.760004  40331.452796  54759.739140  48901.760004
# 4    2017-01-05  48900.903790  41521.021037  55889.819074  48900.903790
# ...         ...           ...           ...           ...           ...
# 1455 2020-12-26  34614.534624  23107.578590  38803.909372  32760.504254
# 1456 2020-12-27  34607.309110  19165.107319  33699.731892  32744.575216
# 1457 2020-12-28  34600.083596  24339.200353  39178.426290  32728.526787
# 1458 2020-12-29  34592.858082  24733.517540  39624.564090  32712.478359
# 1459 2020-12-30  34585.632569  26214.250842  41337.762129  32696.429931
#
#        trend_upper  additive_terms  additive_terms_lower  \
# 0     48904.328644    -9838.114041          -9838.114041
# 1     48903.472430    -4248.277828          -4248.277828
# 2     48902.616217    -3237.932028          -3237.932028
# 3     48901.760004    -1409.333571          -1409.333571
# 4     48900.903790     -295.398494           -295.398494
# ...            ...             ...                   ...
# 1455  36657.606676    -3840.586980          -3840.586980
# 1456  36663.628497    -8575.291024          -8575.291024
# 1457  36668.486219    -3145.230719          -3145.230719
# 1458  36668.244912    -2309.866901          -2309.866901
# 1459  36668.003605     -668.233796           -668.233796
#
#       additive_terms_upper       weekly  weekly_lower  weekly_upper  \
# 0             -9838.114041 -6826.534011  -6826.534011  -6826.534011
# 1             -4248.277828 -1086.745399  -1086.745399  -1086.745399
# 2             -3237.932028    33.726251     33.726251     33.726251
# 3             -1409.333571  1931.610463   1931.610463   1931.610463
# 4              -295.398494  3073.710532   3073.710532   3073.710532
# ...                    ...          ...           ...           ...
# 1455          -3840.586980 -2421.487200  -2421.487200  -2421.487200
# 1456          -8575.291024 -6826.534011  -6826.534011  -6826.534011
# 1457          -3145.230719 -1086.745399  -1086.745399  -1086.745399
# 1458          -2309.866901    33.726251     33.726251     33.726251
# 1459           -668.233796  1931.610463   1931.610463   1931.610463
#
#            yearly  yearly_lower  yearly_upper  multiplicative_terms  \
# 0    -3011.580031  -3011.580031  -3011.580031                   0.0
# 1    -3161.532430  -3161.532430  -3161.532430                   0.0
# 2    -3271.658279  -3271.658279  -3271.658279                   0.0
# 3    -3340.944034  -3340.944034  -3340.944034                   0.0
# 4    -3369.109026  -3369.109026  -3369.109026                   0.0
# ...           ...           ...           ...                   ...
# 1455 -1419.099780  -1419.099780  -1419.099780                   0.0
# 1456 -1748.757014  -1748.757014  -1748.757014                   0.0
# 1457 -2058.485320  -2058.485320  -2058.485320                   0.0
# 1458 -2343.593152  -2343.593152  -2343.593152                   0.0
# 1459 -2599.844259  -2599.844259  -2599.844259                   0.0
#
#       multiplicative_terms_lower  multiplicative_terms_upper          yhat
# 0                            0.0                         0.0  39066.214603
# 1                            0.0                         0.0  44655.194602
# 2                            0.0                         0.0  45664.684189
# 3                            0.0                         0.0  47492.426433
# 4                            0.0                         0.0  48605.505296
# ...                          ...                         ...           ...
# 1455                         0.0                         0.0  30773.947643
# 1456                         0.0                         0.0  26032.018085
# 1457                         0.0                         0.0  31454.852877
# 1458                         0.0                         0.0  32282.991182
# 1459                         0.0                         0.0  33917.398773
#
# [1460 rows x 19 columns]

# %%
forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail()
# Out:
#              ds          yhat    yhat_lower    yhat_upper
# 1455 2020-12-26  30773.947643  23107.578590  38803.909372
# 1456 2020-12-27  26032.018085  19165.107319  33699.731892
# 1457 2020-12-28  31454.852877  24339.200353  39178.426290
# 1458 2020-12-29  32282.991182  24733.517540  39624.564090
# 1459 2020-12-30  33917.398773  26214.250842  41337.762129

# %%
plt.figure(figsize = (15,10))
prophet_model.plot(forecast)
plt.title('Predicción con modelo Prophet (Estacion: Illia, tipo de pago: efectivo, resampleo: diario)',fontsize=16)
plt.xlabel('Fecha', fontsize=15)
plt.ylabel('Cantidad de pasos', fontsize=15)
plt.tick_params(labelsize=14)
plt.legend()
# Out:
# WARNING:matplotlib.legend:No handles with labels found to put in legend.

# %% [markdown]
# Conclusion: La prediccion predice la baja de transito por Illia pagado en eefctivo, en el proximo practico validaremos que paso con 2020 y tambien veremos como afecto la pandemia a nuestras prediciones

# %%
y_test_pred= forecast.yhat.values.reshape(-1, 1)

# %%
plt.figure(figsize = (15,10))
# Series de datos de la gráfica

plt.plot(future.ds, y_test_pred, label = 'y_test_pred',  lw = 1)
plt.plot(df_prophet.ds, df_prophet.y, label = 'y_train',lw = 1)
#Formato de la gráfica
plt.title('Predicción 2020 con modelo Prophet (Estacion: Illia, tipo de pago: efectivo, resampleo: diario)',fontsize=16)
plt.xlabel('Fecha', fontsize=14)
plt.ylabel('Cantidad de pasos', fontsize=14)
plt.legend()

# %%
fig2 = prophet_model.plot_components(forecast,weekly_start=1)

# %% [markdown]
# # **Para pensar, investigar y, opcionalmente, implementar**

# %% [markdown]
# **¿Cómo incorporarías la información sobre tipo de vehículo, forma de pago, sentido, día de la semana, etc.?**
# Este punto lo aplique con un Encoder, encodeando los feathures que me parecieron importantes, y de poder incorporar mas informacion lo haria con mas encoders, lo cual no hay que exedeser para no terminar realizando un set de datos demasiado grande.
#
# **¿Tienen el mismo comportamiento o hay alguna que sea distinta a las otras? Si es así, ¿hay información auxiliar que te ayude a explicar lo que encuentras?**
# No todas las estaciones tienen el mismos comportamiento , hay varias que se habilitaron en 2019 y tiene poco transito y la mayoria es en efectivo
#
# **¿Hay algo que te gustaría investigar o probar?**
# Me gustaria investigar Como afeto la pandemia a el transito en 2020, haciendo una comparacion de su comportamiento versus, los picos de contagios que hubo desde que comenzo todo.
#
# Ademas tengo programado hacer en el informe final redes Neuronales para poder hacer un modelo mas robusto. Y tal vez poder hacer un mix de Redes dependiendo del feathure mas fuerte en cada caso.
# [Fuente De Redes Neuronales en Series de Tiempo ](https://www.aprendemachinelearning.com/pronostico-de-series-temporales-con-redes-neuronales-en-python/)

# %% [markdown]
# # Nueva  ML - Prophet

# %%
diario.head()
# Out:
#             cantidad_pasos  fecha_num
# fecha
# 2017-01-01           31183  170092230
# 2017-01-02           51568  232680596
# 2017-01-03           51093  226053924
# 2017-01-04           53332  236362893
# 2017-01-05           56486  234154212

# %%
temp_train_prophet = diario.loc['2017-01-01':'2019-09-30'] 
temp_train_prophet
# Out:
#             cantidad_pasos  fecha_num
# fecha
# 2017-01-01           31183  170092230
# 2017-01-02           51568  232680596
# 2017-01-03           51093  226053924
# 2017-01-04           53332  236362893
# 2017-01-05           56486  234154212
# ...                    ...        ...
# 2019-09-26           43110   70783488
# 2019-09-27           44985   70046255
# 2019-09-28           41925   70783680
# 2019-09-29           38348   70783776
# 2019-09-30           37170   70046540
#
# [1003 rows x 2 columns]

# %%
temp_test_prophet = diario.loc['2019-09-30':] 
temp_test_prophet
# Out:
#             cantidad_pasos  fecha_num
# fecha
# 2019-09-30           37170   70046540
# 2019-10-01           39669   70783968
# 2019-10-02           34943   70784064
# 2019-10-03           35054   70784160
# 2019-10-04           43775   70784256
# ...                    ...        ...
# 2019-12-27           40182   70792320
# 2019-12-28           30681   70792416
# 2019-12-29           26259   70792512
# 2019-12-30           34523   70055185
# 2019-12-31           21447   65630736
#
# [93 rows x 2 columns]

# %%
#Armamos nuestro dataset para poder buscar la predicción de 2020
df_prophet_test = temp_test_prophet.reset_index().drop(columns='fecha_num').rename(columns={'fecha':'ds', 'cantidad_pasos':'y'})
df_prophet_test
# Out:
#            ds      y
# 0  2019-09-30  37170
# 1  2019-10-01  39669
# 2  2019-10-02  34943
# 3  2019-10-03  35054
# 4  2019-10-04  43775
# ..        ...    ...
# 88 2019-12-27  40182
# 89 2019-12-28  30681
# 90 2019-12-29  26259
# 91 2019-12-30  34523
# 92 2019-12-31  21447
#
# [93 rows x 2 columns]

# %%
#Armamos nuestro dataset para poder buscar la predicción de 2020
df_prophet_train = temp_train_prophet.reset_index().drop(columns='fecha_num').rename(columns={'fecha':'ds', 'cantidad_pasos':'y'})
df_prophet_train
# Out:
#              ds      y
# 0    2017-01-01  31183
# 1    2017-01-02  51568
# 2    2017-01-03  51093
# 3    2017-01-04  53332
# 4    2017-01-05  56486
# ...         ...    ...
# 998  2019-09-26  43110
# 999  2019-09-27  44985
# 1000 2019-09-28  41925
# 1001 2019-09-29  38348
# 1002 2019-09-30  37170
#
# [1003 rows x 2 columns]

# %%
# Omitimos los diferentes warnings que se generan con el uso de las librerias
import warnings
warnings.simplefilter('ignore')
# Importamos la librería
from fbprophet import Prophet

# %%
# Instanciamos el modelo
prophet_model = Prophet()

# %%
# Entrenamos nuestro modelo con los datos de entrenamiento
prophet_model.fit(df_prophet_train)
# Out:
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
df_train_prophet_pred = prophet_model.predict(df_prophet_train)[['ds','yhat']]
df_train_prophet_pred
# Out:
#              ds          yhat
# 0    2017-01-01  39320.926212
# 1    2017-01-02  45088.755791
# 2    2017-01-03  46242.746410
# 3    2017-01-04  48018.014647
# 4    2017-01-05  49057.929123
# ...         ...           ...
# 998  2019-09-26  42903.246029
# 999  2019-09-27  45168.564971
# 1000 2019-09-28  37153.474919
# 1001 2019-09-29  32741.680531
# 1002 2019-09-30  38656.414619
#
# [1003 rows x 2 columns]

# %%
df_test_prophet_pred = prophet_model.predict(df_prophet_test)[['ds','yhat']]
df_test_prophet_pred
# Out:
#            ds          yhat
# 0  2019-09-30  38656.414619
# 1  2019-10-01  39925.175432
# 2  2019-10-02  41783.501311
# 3  2019-10-03  42875.893010
# 4  2019-10-04  45153.501537
# ..        ...           ...
# 88 2019-12-27  43824.597788
# 89 2019-12-28  35519.088221
# 90 2019-12-29  30834.322519
# 91 2019-12-30  36496.338487
# 92 2019-12-31  37534.889466
#
# [93 rows x 2 columns]

# %%
y_train_pred = df_train_prophet_pred.yhat.values.reshape(-1, 1)
y_test_pred= df_test_prophet_pred.yhat.values.reshape(-1, 1)

# %%
y_train= temp_train_prophet.cantidad_pasos.values.reshape(-1, 1) 
y_test= temp_test_prophet.cantidad_pasos.values.reshape(-1, 1)

# %%
plt.figure(figsize = (15,10))
# Series de datos de la gráfica
plt.plot(temp_train_prophet.index, y_train, label = 'y_train')
plt.plot(temp_test_prophet.index, y_test, label = 'y_test')
plt.plot(temp_train_prophet.index, y_train_pred, label = 'y_train_pred', color='yellow', lw = 2)
plt.plot(temp_test_prophet.index, y_test_pred, label = 'y_test_pred',  lw = 2)
#Formato de la gráfica
plt.title('Predicción con modelo Prophet (Estacion: Illia, tipo de pago: efectivo, resampleo: diario)',fontsize=16)
plt.xlabel('Fecha', fontsize=15)
plt.ylabel('Cantidad de pasos', fontsize=15)
plt.tick_params(labelsize=14)
plt.legend()

# %%
evaluar_modelo('Prophet', y_train, y_test, y_train_pred, y_test_pred)
# Out:
# El modelo a evaluar:  Prophet
# Raíz del error cuadrático medio en Train: 5701.4
# Raíz del error cuadrático medio en Test: 5825.1
# Error Absoluto medio en Train: 359455.2
# Error Absoluto medio en Test: 424016.1

# %% [markdown]
# Este Modelo nos Dio un error mucho mas alto que el modelo que habiamos elegido anteriormente  "XGBoost Optimizado". Por lo tanto no lo elegiriamos como el mejor Modelo
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # Ahora, voy a verificar si la pandemia hizo disminuir el transito.

# %%
data_2020 = pd.read_csv('Datasets/flujo-vehicular-2020.csv', sep =',')

# %%
data_2019.info()
data_2019.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 812153 entries, 0 to 812152
# Data columns (total 10 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   periodo         812153 non-null  int64
#  1   fecha           812153 non-null  object
#  2   hora_inicio     812153 non-null  int64
#  3   hora_fin        812153 non-null  int64
#  4   dia             812153 non-null  object
#  5   estacion        812153 non-null  object
#  6   sentido         812153 non-null  object
#  7   tipo_vehiculo   812153 non-null  object
#  8   forma_pago      812153 non-null  object
#  9   cantidad_pasos  812153 non-null  int64
# dtypes: int64(4), object(6)
# memory usage: 62.0+ MB
#    periodo       fecha  hora_inicio  hora_fin     dia    estacion    sentido  \
# 0     2019  2019-01-01            0         1  Martes     Alberti     Centro
# 1     2019  2019-01-01            0         1  Martes     Alberti     Centro
# 2     2019  2019-01-01            0         1  Martes     Alberti  Provincia
# 3     2019  2019-01-01            0         1  Martes     Alberti  Provincia
# 4     2019  2019-01-01            0         1  Martes  Avellaneda     Centro
#
#   tipo_vehiculo  forma_pago  cantidad_pasos
# 0       Liviano  NO COBRADO              22
# 1       Liviano    TELEPASE               6
# 2       Liviano  NO COBRADO              53
# 3       Liviano    TELEPASE              18
# 4       Liviano    EFECTIVO              16

# %%
data_2020.info()
data_2020.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2533743 entries, 0 to 2533742
# Data columns (total 13 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   periodo         float64
#  1   fecha           object
#  2   mes             object
#  3   dia             object
#  4   dia_fecha       float64
#  5   hora_inicio     float64
#  6   hora_fin        float64
#  7   estacion        object
#  8   tipo_vehiculo   object
#  9   forma_pago      object
#  10  observacion     object
#  11  sentido         object
#  12  cantidad_pasos  float64
# dtypes: float64(5), object(8)
# memory usage: 251.3+ MB
#    periodo                fecha    mes        dia  dia_fecha  hora_inicio  \
# 0   2020.0  2020-01-01 00:00:00  enero  Miércoles        1.0          0.0
# 1   2020.0  2020-01-01 00:00:00  enero  Miércoles        1.0          0.0
# 2   2020.0  2020-01-01 00:00:00  enero  Miércoles        1.0          0.0
# 3   2020.0  2020-01-01 00:00:00  enero  Miércoles        1.0          0.0
# 4   2020.0  2020-01-01 00:00:00  enero  Miércoles        1.0          0.0
#
#    hora_fin estacion tipo_vehiculo forma_pago  \
# 0       1.0  ALBERDI          Auto   Efectivo
# 1       1.0  ALBERDI          Auto   Efectivo
# 2       1.0  ALBERDI          Auto  Rec.Deuda
# 3       1.0  ALBERDI          Auto  Rec.Deuda
# 4       1.0  ALBERDI          Auto  Rec.Deuda
#
#                         observacion    sentido  cantidad_pasos
# 0                          Efectivo     Centro            24.0
# 1                          Efectivo  Provincia            80.0
# 2                Paso en Infracción  Provincia             1.0
# 3  Paso en infracción con Multa LPR     Centro             1.0
# 4  Paso en infracción con Multa LPR  Provincia             1.0

# %% [markdown]
# De inicio vemos mas registros en 2020, Vamos a comparar 2019 versus 2020, ya que 2019 marcaba un gran ascenso de transito

# %%
#Unimos los 3 datasets, podemos hacerlo asi directamente ya que tienen las mismas columnas
dataset_2019_2020 = pd.concat([data_2019, data_2020])
dataset_2019_2020.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3345896 entries, 0 to 2533742
# Data columns (total 13 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   periodo         float64
#  1   fecha           object
#  2   hora_inicio     float64
#  3   hora_fin        float64
#  4   dia             object
#  5   estacion        object
#  6   sentido         object
#  7   tipo_vehiculo   object
#  8   forma_pago      object
#  9   cantidad_pasos  float64
#  10  mes             object
#  11  dia_fecha       float64
#  12  observacion     object
# dtypes: float64(5), object(8)
# memory usage: 357.4+ MB

# %%
#Realizamos los mismos pasos de tratamiento

#Pasamos la columna fecha a formato datetime, y le unimos la hora_fin como hora
dataset_2019_2020['fecha2'] = pd.to_datetime(dataset_2019_2020.fecha) + pd.to_timedelta(dataset_2019_2020.hora_fin, unit = 'h')

# %%
dataset_2019_2020['fecha_num'] = dataset_2019_2020.fecha2.map(datetime.toordinal)
dataset_2019_2020.head()
# Out:
#    periodo       fecha  hora_inicio  hora_fin     dia    estacion    sentido  \
# 0   2019.0  2019-01-01          0.0       1.0  Martes     Alberti     Centro
# 1   2019.0  2019-01-01          0.0       1.0  Martes     Alberti     Centro
# 2   2019.0  2019-01-01          0.0       1.0  Martes     Alberti  Provincia
# 3   2019.0  2019-01-01          0.0       1.0  Martes     Alberti  Provincia
# 4   2019.0  2019-01-01          0.0       1.0  Martes  Avellaneda     Centro
#
#   tipo_vehiculo  forma_pago  cantidad_pasos  mes  dia_fecha observacion  \
# 0       Liviano  NO COBRADO            22.0  NaN        NaN         NaN
# 1       Liviano    TELEPASE             6.0  NaN        NaN         NaN
# 2       Liviano  NO COBRADO            53.0  NaN        NaN         NaN
# 3       Liviano    TELEPASE            18.0  NaN        NaN         NaN
# 4       Liviano    EFECTIVO            16.0  NaN        NaN         NaN
#
#                fecha2  fecha_num
# 0 2019-01-01 01:00:00     737060
# 1 2019-01-01 01:00:00     737060
# 2 2019-01-01 01:00:00     737060
# 3 2019-01-01 01:00:00     737060
# 4 2019-01-01 01:00:00     737060

# %%
#Quitamos las columnas fecha y hora_fin ya que las incluimos en el campo fecha2
dataset_2019_2020.drop(columns=['fecha','hora_fin'], inplace = True)

# %%
#Corregimos el nombre de fecha2 a fecha
dataset_2019_2020.rename(columns = {'fecha2':'fecha'}, inplace = True) 
dataset_2019_2020.head()
# Out:
#    periodo  hora_inicio     dia    estacion    sentido tipo_vehiculo  \
# 0   2019.0          0.0  Martes     Alberti     Centro       Liviano
# 1   2019.0          0.0  Martes     Alberti     Centro       Liviano
# 2   2019.0          0.0  Martes     Alberti  Provincia       Liviano
# 3   2019.0          0.0  Martes     Alberti  Provincia       Liviano
# 4   2019.0          0.0  Martes  Avellaneda     Centro       Liviano
#
#    forma_pago  cantidad_pasos  mes  dia_fecha observacion               fecha  \
# 0  NO COBRADO            22.0  NaN        NaN         NaN 2019-01-01 01:00:00
# 1    TELEPASE             6.0  NaN        NaN         NaN 2019-01-01 01:00:00
# 2  NO COBRADO            53.0  NaN        NaN         NaN 2019-01-01 01:00:00
# 3    TELEPASE            18.0  NaN        NaN         NaN 2019-01-01 01:00:00
# 4    EFECTIVO            16.0  NaN        NaN         NaN 2019-01-01 01:00:00
#
#    fecha_num
# 0     737060
# 1     737060
# 2     737060
# 3     737060
# 4     737060

# %%
# Graficamos distribucion por estacion y año
from matplotlib.pyplot import show
dataset_forma_pago=pd.DataFrame(dataset_2019_2020.groupby([dataset_2019_2020.forma_pago, dataset_2019_2020.periodo])['cantidad_pasos'].mean()).reset_index()
dataset_forma_pago=dataset_forma_pago.sort_values(by='cantidad_pasos' ,ascending = False)
plt.figure(figsize=(16,8))
g=sns.barplot(data=dataset_forma_pago,y='cantidad_pasos', x='periodo', hue='forma_pago', palette =sns.color_palette("tab10",15))
#plt.set_xticklabel( rotation=90) # Rotate labels
plt.title("Pases por año y forma de pago")
plt.ylabel('Promedio de Pasos')
plt.xlabel('Año')
# Out:
# Text(0.5, 0, 'Año')

# %% [raw]
# Observamos que bajo considerablemente el transito, y el pago en efectivo en 2020 se ve muy poco , en Pandemia se dieron beneficios exentos a personal de salud por ejemplo, vemos que el exento es el mas alto de 2020

# %%
dataset_analisis_2020 =  dataset_2019_2020[['fecha','forma_pago','cantidad_pasos']]\
        .groupby(['fecha', 'forma_pago'])\
        .sum().reset_index()
dataset_analisis_2020
# Out:
#                      fecha       forma_pago  cantidad_pasos
# 0      2019-01-01 00:00:00         EFECTIVO     5089.000000
# 1      2019-01-01 00:00:00           EXENTO       73.000000
# 2      2019-01-01 00:00:00       INFRACCION       38.000000
# 3      2019-01-01 00:00:00       NO COBRADO      120.000000
# 4      2019-01-01 00:00:00  T. DISCAPACIDAD       68.000000
# ...                    ...              ...             ...
# 100573 2020-12-31 22:00:00        Violación     2727.251539
# 100574 2020-12-31 23:00:00           Exento        9.915789
# 100575 2020-12-31 23:00:00     Mercado Pago       72.747367
# 100576 2020-12-31 23:00:00              Tag     1672.957723
# 100577 2020-12-31 23:00:00        Violación     1065.321872
#
# [100578 rows x 3 columns]

# %%
plt.figure(figsize=(18, 12))
sns.lineplot(data=dataset_analisis_2020, x='fecha', y='cantidad_pasos', hue='forma_pago',  palette = 'viridis')

#Formato de la gráfica
plt.title('Cantidad de pasos Vs fecha (resampleo:diario, agregado: forma de pago)',fontsize=16)
plt.xlabel('Fecha', fontsize=15)
plt.ylabel('Cantidad de pasos', fontsize=15)
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.tick_params(labelsize=14)
plt.show()

# %% [raw]
# Aca se Observa que no hubo mucho transito en el mes 202003 que fue donde de comenzo la cuarentena estricta

# %%
# Teniendo en cuenta que el 2020 tiene las estaciones en mayuscula, paso todas las etsaciones a mayuscula para poder compararlas
dataset_2019_2020["ESTACION"] = dataset_2019_2020["estacion"].str.upper()
dataset_2019_2020
# Out:
#          periodo  hora_inicio     dia                          estacion  \
# 0         2019.0          0.0  Martes                           Alberti
# 1         2019.0          0.0  Martes                           Alberti
# 2         2019.0          0.0  Martes                           Alberti
# 3         2019.0          0.0  Martes                           Alberti
# 4         2019.0          0.0  Martes                        Avellaneda
# ...          ...          ...     ...                               ...
# 2533738   2020.0         21.0  Jueves  DELLEPIANE LINIERSLEPIANE CENTRO
# 2533739   2020.0         21.0  Jueves                DELLEPIANE LINIERS
# 2533740   2020.0         21.0  Jueves                               ILP
# 2533741   2020.0         22.0  Jueves                               ILP
# 2533742   2020.0         23.0  Jueves                DELLEPIANE LINIERS
#
#            sentido   tipo_vehiculo  forma_pago  cantidad_pasos        mes  \
# 0           Centro         Liviano  NO COBRADO            22.0        NaN
# 1           Centro         Liviano    TELEPASE             6.0        NaN
# 2        Provincia         Liviano  NO COBRADO            53.0        NaN
# 3        Provincia         Liviano    TELEPASE            18.0        NaN
# 4           Centro         Liviano    EFECTIVO            16.0        NaN
# ...            ...             ...         ...             ...        ...
# 2533738     Centro  Pesados 6 Ejes         Tag             1.0  diciembre
# 2533739  Provincia  Pesados 6 Ejes         Tag             1.0  diciembre
# 2533740     Centro  Pesados 6 Ejes         Tag             1.0  diciembre
# 2533741     Centro  Pesados 6 Ejes         Tag             2.0  diciembre
# 2533742  Provincia  Pesados 6 Ejes         Tag             1.0  diciembre
#
#          dia_fecha        observacion               fecha  fecha_num  \
# 0              NaN                NaN 2019-01-01 01:00:00     737060
# 1              NaN                NaN 2019-01-01 01:00:00     737060
# 2              NaN                NaN 2019-01-01 01:00:00     737060
# 3              NaN                NaN 2019-01-01 01:00:00     737060
# 4              NaN                NaN 2019-01-01 01:00:00     737060
# ...            ...                ...                 ...        ...
# 2533738       31.0  Tag - PosPago OCR 2020-12-31 22:00:00     737790
# 2533739       31.0      Tag - PosPago 2020-12-31 22:00:00     737790
# 2533740       31.0      Tag - PosPago 2020-12-31 22:00:00     737790
# 2533741       31.0      Tag - PosPago 2020-12-31 23:00:00     737790
# 2533742       31.0  Tag - PosPago OCR 2020-12-31 00:00:00     737790
#
#                                  ESTACION
# 0                                 ALBERTI
# 1                                 ALBERTI
# 2                                 ALBERTI
# 3                                 ALBERTI
# 4                              AVELLANEDA
# ...                                   ...
# 2533738  DELLEPIANE LINIERSLEPIANE CENTRO
# 2533739                DELLEPIANE LINIERS
# 2533740                               ILP
# 2533741                               ILP
# 2533742                DELLEPIANE LINIERS
#
# [3345896 rows x 14 columns]

# %%
dataset_completo_año=pd.DataFrame(dataset_2019_2020.groupby([dataset_2019_2020.ESTACION, dataset_2019_2020.periodo])['cantidad_pasos'].mean()).reset_index()
dataset_completo_año['Descripcion']=dataset_completo_año["ESTACION"]+" - "+dataset_completo_año["periodo"].astype(str)
dataset_completo_año.info()
dataset_completo_año
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21 entries, 0 to 20
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   ESTACION        21 non-null     object
#  1   periodo         21 non-null     float64
#  2   cantidad_pasos  21 non-null     float64
#  3   Descripcion     21 non-null     object
# dtypes: float64(2), object(2)
# memory usage: 800.0+ bytes
#                             ESTACION  periodo  cantidad_pasos  \
# 0                            ALBERDI   2020.0       19.568161
# 1                            ALBERTI   2019.0       42.572147
# 2                         AVELLANEDA   2019.0      259.079853
# 3                         AVELLANEDA   2020.0       59.703611
# 4                         DELLEPIANE   2019.0      156.159104
# 5                 DELLEPIANE LINIERS   2020.0       41.255785
# 6   DELLEPIANE LINIERSLEPIANE CENTRO   2020.0       42.406301
# 7                              ILLIA   2019.0      211.968790
# 8                              ILLIA   2020.0       60.665192
# 9                                ILP   2020.0       11.627061
# 10                               PB1   2020.0       13.701385
# 11                               PB2   2020.0        7.762122
# 12                               PB3   2020.0        7.693635
# 13                               PB4   2020.0       11.754488
# 14                               PDB   2019.0      138.374573
# 15                            RETIRO   2019.0       21.685039
# 16                            RETIRO   2020.0        7.546359
# 17                          SALGUERO   2019.0       49.112550
# 18                          SALGUERO   2020.0       17.864560
# 19                         SARMIENTO   2019.0       50.810687
# 20                         SARMIENTO   2020.0       17.275965
#
#                                   Descripcion
# 0                            ALBERDI - 2020.0
# 1                            ALBERTI - 2019.0
# 2                         AVELLANEDA - 2019.0
# 3                         AVELLANEDA - 2020.0
# 4                         DELLEPIANE - 2019.0
# 5                 DELLEPIANE LINIERS - 2020.0
# 6   DELLEPIANE LINIERSLEPIANE CENTRO - 2020.0
# 7                              ILLIA - 2019.0
# 8                              ILLIA - 2020.0
# 9                                ILP - 2020.0
# 10                               PB1 - 2020.0
# 11                               PB2 - 2020.0
# 12                               PB3 - 2020.0
# 13                               PB4 - 2020.0
# 14                               PDB - 2019.0
# 15                            RETIRO - 2019.0
# 16                            RETIRO - 2020.0
# 17                          SALGUERO - 2019.0
# 18                          SALGUERO - 2020.0
# 19                         SARMIENTO - 2019.0
# 20                         SARMIENTO - 2020.0

# %%
# Graficamos distribucion por estacion y año
from matplotlib.pyplot import show
dataset_completo_año=dataset_completo_año.sort_values(by='cantidad_pasos' ,ascending = False)
plt.figure(figsize=(16,8))
g=sns.barplot(y='ESTACION', x='cantidad_pasos', hue='periodo', data=dataset_completo_año, palette =sns.color_palette("Paired"))
#plt.set_xticklabel( rotation=90) # Rotate labels
plt.title("Pases por estacion")
plt.ylabel('Estacion')
plt.xlabel('Promedio Pasos')
# Out:
# Text(0.5, 0, 'Promedio Pasos')

# %% [raw]
# Observamos que es muy significativa la disminucion del transito en 2020. incluso hay algunas estaciones sin informacion ya demas hay estaciones nuevas en 2020

# %%
#Reordenamos el dataset por fecha
#dataset_2019_2020.set_index('fecha', inplace=True)
dataset_2019_2020.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3345896 entries, 0 to 2533742
# Data columns (total 14 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   periodo         float64
#  1   hora_inicio     float64
#  2   dia             object
#  3   estacion        object
#  4   sentido         object
#  5   tipo_vehiculo   object
#  6   forma_pago      object
#  7   cantidad_pasos  float64
#  8   mes             object
#  9   dia_fecha       float64
#  10  observacion     object
#  11  fecha           datetime64[ns]
#  12  fecha_num       int64
#  13  ESTACION        object
# dtypes: datetime64[ns](1), float64(4), int64(1), object(8)
# memory usage: 382.9+ MB

# %%
diario_2019_2020 = dataset_2019_2020.resample('D', on = 'fecha').sum().reset_index()
print(diario_2019_2020.shape)
diario_2019_2020.head()
# Out:
# (731, 6)
#        fecha    periodo  hora_inicio  cantidad_pasos  dia_fecha   fecha_num
# 0 2019-01-01  3634200.0      21864.0        208866.0        0.0  1326708000
# 1 2019-01-02  4461990.0      26166.0        378827.0        0.0  1628904810
# 2 2019-01-03  4476123.0      26406.0        394887.0        0.0  1634066454
# 3 2019-01-04  4379211.0      25653.0        368028.0        0.0  1598689647
# 4 2019-01-05  3874461.0      22659.0        200453.0        0.0  1414425816

# %%
plt.figure(figsize = (15,5))
plt.plot(diario_2019_2020.fecha, diario_2019_2020.cantidad_pasos)
plt.xlabel('Tiempo')
plt.ylabel('Cantidad de autos, por dia')
plt.title('Transito con Resampleo Diario')
plt.show()

# %% [raw]
# En este resampleo, podemos deducir que en Febrero y Marzo 2021 no hubo pasos o medicion de los peajes, y coincide cuando se declaro cuarentena total en Argentina. y Tambien observamos como con el pasar del año 2020, el pase de autos por autopistas vuelve a sus valores normales.

# %%
WEEK_2019_2020 = dataset_2019_2020.resample('w', on = 'fecha').sum().reset_index()
print(WEEK_2019_2020.shape)
WEEK_2019_2020.head()
# Out:
# (105, 6)
#        fecha     periodo  hora_inicio  cantidad_pasos  dia_fecha    fecha_num
# 0 2019-01-06  25362678.0     149176.0       1856627.0        0.0   9258979782
# 1 2019-01-13  31544856.0     186037.0       2318105.0        0.0  11515964286
# 2 2019-01-20  29713623.0     173901.0       2093993.0        0.0  10847546405
# 3 2019-01-27  29739870.0     174106.0       2075190.0        0.0  10857231645
# 4 2019-02-03  30038682.0     174914.0       2216784.0        0.0  10966424553

# %%
plt.figure(figsize = (15,5))
plt.plot(WEEK_2019_2020.fecha, WEEK_2019_2020.cantidad_pasos)
plt.xlabel('Tiempo')
plt.ylabel('Cantidad de autos, por semana')
plt.title('Transito con Resampleo Semanal')
plt.show()

# %% [markdown]
# FUENTE DE INFORMACIPON DE LA CUARENTENA
#
# https://www.bbc.com/mundo/noticias-america-latina-51975331#:~:text=Argentina%20anunci%C3%B3%20el%20aislamiento%20social,hasta%20el%2031%20de%20marzo.
#
#
# ![image.png](attachment:image.png)
